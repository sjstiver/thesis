# %%
# changed kmeans distortion to calculate delta every iteration instead of every epoch

import numpy as np
import scipy as sp
import distances
import gr_kmeans
import gr_lbg
import matplotlib.pyplot as plt
import plots
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from subspaces import make_subspaces

# %%
data, labels = load_ip_data([10, 11, 12], sample_size = 10000)
# Out:
# Class 10 name: Soybean-notill
# Sample number for class 10 reduced to 972
# Class 11 name: Soybean-mintill
# Sample number for class 11 reduced to 2455
# Class 12 name: Soybean-clean
# Sample number for class 12 reduced to 593

# %% [markdown]
# ### Gr(5, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=5)

# %%
dist_metric = 'geodesic'
D = distances.geodesic_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.title('Embedded Data')
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2286.9751
# Cluster purity calculations:
# Average cluster purity: 0.6332 +/- 0.0204
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6164
# Classification BSR based on highest probability labels:
# BSR: 0.6332

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100, 
                                  dist_metric=dist_metric)
# Out:
# LBG terminated after 12 iterations
#
# Final cluster distortion: 2267.4723
# Cluster purity calculations:
# Average cluster purity: 0.6377 +/- 0.0089
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6625
# Classification BSR based on highest probability labels:
# BSR: 0.6377

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2082.0437
# Cluster purity calculations:
# Average cluster purity: 0.6619 +/- 0.0240
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6787
# Classification BSR based on highest probability labels:
# BSR: 0.6619

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100, 
                                  dist_metric=dist_metric)
# Out:
# LBG terminated after 15 iterations
#
# Final cluster distortion: 2099.8304
# Cluster purity calculations:
# Average cluster purity: 0.6742 +/- 0.0168
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6600
# Classification BSR based on highest probability labels:
# BSR: 0.6742

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2070.5733
# Cluster purity calculations:
# Average cluster purity: 0.7557 +/- 0.0383
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6737
# Classification BSR based on highest probability labels:
# BSR: 0.7557

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 22 iterations
#
# Final cluster distortion: 1993.5833
# Cluster purity calculations:
# Average cluster purity: 0.6953 +/- 0.0143
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6961
# Classification BSR based on highest probability labels:
# BSR: 0.6953

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ### Gr(10, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=10)

# %%
D = distances.geodesic_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2321.9740
# Cluster purity calculations:
# Average cluster purity: 0.7272 +/- 0.0262
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7431
# Classification BSR based on highest probability labels:
# BSR: 0.7272

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 7 iterations
#
# Final cluster distortion: 2326.5037
# Cluster purity calculations:
# Average cluster purity: 0.6934 +/- 0.0425
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6459
# Classification BSR based on highest probability labels:
# BSR: 0.6934

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2254.6877
# Cluster purity calculations:
# Average cluster purity: 0.7136 +/- 0.0429
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6658
# Classification BSR based on highest probability labels:
# BSR: 0.7136

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 17 iterations
#
# Final cluster distortion: 2193.2363
# Cluster purity calculations:
# Average cluster purity: 0.7503 +/- 0.0113
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7581
# Classification BSR based on highest probability labels:
# BSR: 0.7503

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2206.6492
# Cluster purity calculations:
# Average cluster purity: 0.7272 +/- 0.0476
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6858
# Classification BSR based on highest probability labels:
# BSR: 0.7272

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 25 iterations
#
# Final cluster distortion: 2120.6866
# Cluster purity calculations:
# Average cluster purity: 0.7942 +/- 0.0088
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7955
# Classification BSR based on highest probability labels:
# BSR: 0.7942

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ### Gr(15,200)

# %%
sub, lbls = make_subspaces(data, labels, dim=15)

# %%
D = distances.geodesic_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2272.4747
# Cluster purity calculations:
# Average cluster purity: 0.8378 +/- 0.0204
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7895
# Classification BSR based on highest probability labels:
# BSR: 0.8378

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 6 iterations
#
# Final cluster distortion: 2226.2794
# Cluster purity calculations:
# Average cluster purity: 0.7589 +/- 0.0215
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7519
# Classification BSR based on highest probability labels:
# BSR: 0.7589

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2131.3155
# Cluster purity calculations:
# Average cluster purity: 0.8512 +/- 0.0414
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7707
# Classification BSR based on highest probability labels:
# BSR: 0.8512

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 6 iterations
#
# Final cluster distortion: 2106.3255
# Cluster purity calculations:
# Average cluster purity: 0.8795 +/- 0.0103
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8647
# Classification BSR based on highest probability labels:
# BSR: 0.8795

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)
