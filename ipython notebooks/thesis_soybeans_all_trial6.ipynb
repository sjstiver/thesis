# %%
import numpy as np
import scipy as sp
import distances
import gr_kmeans
import gr_lbg
import matplotlib.pyplot as plt
import plots
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from subspaces import make_subspaces

# %%
data, labels = load_ip_data([10, 11, 12], sample_size = 10000)
# Out:
# Class 10 name: Soybean-notill
# Sample number for class 10 reduced to 972
# Class 11 name: Soybean-mintill
# Sample number for class 11 reduced to 2455
# Class 12 name: Soybean-clean
# Sample number for class 12 reduced to 593

# %% [markdown]
# ### Gr(5, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=5)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.title('Embedded Data')
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1461.0638
# Cluster purity calculations:
# Average cluster purity: 0.6644 +/- 0.0046
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6775
# Classification BSR based on highest probability labels:
# BSR: 0.6644

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 14 iterations
#
# Final cluster distortion: 1430.8295
# Cluster purity calculations:
# Average cluster purity: 0.6926 +/- 0.0190
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6824
# Classification BSR based on highest probability labels:
# BSR: 0.6926

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1419.9072
# Cluster purity calculations:
# Average cluster purity: 0.7741 +/- 0.0480
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6488
# Classification BSR based on highest probability labels:
# BSR: 0.7741

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 18 iterations
#
# Final cluster distortion: 1361.4906
# Cluster purity calculations:
# Average cluster purity: 0.7036 +/- 0.0209
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6787
# Classification BSR based on highest probability labels:
# BSR: 0.7036

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1378.4561
# Cluster purity calculations:
# Average cluster purity: 0.7283 +/- 0.0400
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7086
# Classification BSR based on highest probability labels:
# BSR: 0.7283

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100)
# Out:
# LBG terminated after 24 iterations
#
# Final cluster distortion: 1321.7270
# Cluster purity calculations:
# Average cluster purity: 0.7814 +/- 0.0103
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7634
# Classification BSR based on highest probability labels:
# BSR: 0.7814

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ### Gr(10, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=10)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1488.4088
# Cluster purity calculations:
# Average cluster purity: 0.8705 +/- 0.0171
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7207
# Classification BSR based on highest probability labels:
# BSR: 0.8705

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 18 iterations
#
# Final cluster distortion: 1417.2111
# Cluster purity calculations:
# Average cluster purity: 0.7301 +/- 0.0223
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7082
# Classification BSR based on highest probability labels:
# BSR: 0.7301

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1424.0560
# Cluster purity calculations:
# Average cluster purity: 0.6988 +/- 0.0425
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6983
# Classification BSR based on highest probability labels:
# BSR: 0.6988

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 19 iterations
#
# Final cluster distortion: 1361.8941
# Cluster purity calculations:
# Average cluster purity: 0.8522 +/- 0.0147
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8429
# Classification BSR based on highest probability labels:
# BSR: 0.8522

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1433.3173
# Cluster purity calculations:
# Average cluster purity: 0.9224 +/- 0.0289
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6783
# Classification BSR based on highest probability labels:
# BSR: 0.9224

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100)
# Out:
# LBG terminated after 11 iterations
#
# Final cluster distortion: 1336.3498
# Cluster purity calculations:
# Average cluster purity: 0.7376 +/- 0.0221
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7955
# Classification BSR based on highest probability labels:
# BSR: 0.7376

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ### Gr(15,200)

# %%
sub, lbls = make_subspaces(data, labels, dim=15)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1404.4622
# Cluster purity calculations:
# Average cluster purity: 0.8346 +/- 0.0223
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7857
# Classification BSR based on highest probability labels:
# BSR: 0.8346

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 8 iterations
#
# Final cluster distortion: 1336.2402
# Cluster purity calculations:
# Average cluster purity: 0.8694 +/- 0.0040
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8872
# Classification BSR based on highest probability labels:
# BSR: 0.8694

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1396.2244
# Cluster purity calculations:
# Average cluster purity: 0.9138 +/- 0.0153
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7218
# Classification BSR based on highest probability labels:
# BSR: 0.9138

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 10 iterations
#
# Final cluster distortion: 1291.6064
# Cluster purity calculations:
# Average cluster purity: 0.8950 +/- 0.0147
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8496
# Classification BSR based on highest probability labels:
# BSR: 0.8950

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)
