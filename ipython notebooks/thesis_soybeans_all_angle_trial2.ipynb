# %%
# changed kmeans distortion to calculate delta every iteration instead of every epoch

import numpy as np
import scipy as sp
import distances
import gr_kmeans
import gr_lbg
import matplotlib.pyplot as plt
import plots
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from subspaces import make_subspaces

# %%
data, labels = load_ip_data([10, 11, 12], sample_size = 10000)
# Out:
# Class 10 name: Soybean-notill
# Sample number for class 10 reduced to 972
# Class 11 name: Soybean-mintill
# Sample number for class 11 reduced to 2455
# Class 12 name: Soybean-clean
# Sample number for class 12 reduced to 593

# %% [markdown]
# ### Gr(5, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=5)

# %%
dist_metric = 'angle'
D = distances.prin_angle_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.title('Embedded Data')
plt.show()

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 5.0605
# Cluster purity calculations:
# Average cluster purity: 0.7795 +/- 0.0409
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8344
# Classification BSR based on highest probability labels:
# BSR: 0.7795

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100, 
                                  dist_metric=dist_metric)
# Out:
# LBG terminated after 100 iterations
#
# Final cluster distortion: 4.7477
# Cluster purity calculations:
# Average cluster purity: 0.8346 +/- 0.0226
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8418
# Classification BSR based on highest probability labels:
# BSR: 0.8346

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 62 iterations
#
# Final cluster distortion: 4.8607
# Cluster purity calculations:
# Average cluster purity: 0.8042 +/- 0.0499
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8257
# Classification BSR based on highest probability labels:
# BSR: 0.8042

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 100 iterations
#
# Final cluster distortion: 4.5961
# Cluster purity calculations:
# Average cluster purity: 0.8848 +/- 0.0098
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8842
# Classification BSR based on highest probability labels:
# BSR: 0.8848

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ### Gr(10, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=10)

# %%
D = distances.prin_angle_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 5 iterations
#
# Final cluster distortion: 1.2486
# Cluster purity calculations:
# Average cluster purity: 0.8756 +/- 0.0081
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8254
# Classification BSR based on highest probability labels:
# BSR: 0.8756

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 8 iterations
#
# Final cluster distortion: 1.1040
# Cluster purity calculations:
# Average cluster purity: 0.9560 +/- 0.0015
# Classification accuracy based on highest probability labels:
# Accuracy: 0.9526
# Classification BSR based on highest probability labels:
# BSR: 0.9560

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1.1852
# Cluster purity calculations:
# Average cluster purity: 0.9837 +/- 0.0010
# Classification accuracy based on highest probability labels:
# Accuracy: 0.9401
# Classification BSR based on highest probability labels:
# BSR: 0.9837

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 100 iterations
#
# Final cluster distortion: 1.0756
# Cluster purity calculations:
# Average cluster purity: 0.9840 +/- 0.0004
# Classification accuracy based on highest probability labels:
# Accuracy: 0.9726
# Classification BSR based on highest probability labels:
# BSR: 0.9840

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 14 iterations
#
# Final cluster distortion: 1.1887
# Cluster purity calculations:
# Average cluster purity: 0.9585 +/- 0.0049
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8978
# Classification BSR based on highest probability labels:
# BSR: 0.9585

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 100 iterations
#
# Final cluster distortion: 1.0759
# Cluster purity calculations:
# Average cluster purity: 0.9874 +/- 0.0004
# Classification accuracy based on highest probability labels:
# Accuracy: 0.9751
# Classification BSR based on highest probability labels:
# BSR: 0.9874

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ### Gr(15,200)

# %%
sub, lbls = make_subspaces(data, labels, dim=15)

# %%
D = distances.prin_angle_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 4 iterations
#
# Final cluster distortion: 0.5294
# Cluster purity calculations:
# Average cluster purity: 0.8269 +/- 0.0186
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8571
# Classification BSR based on highest probability labels:
# BSR: 0.8269

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 5 iterations
#
# Final cluster distortion: 0.4572
# Cluster purity calculations:
# Average cluster purity: 0.9908 +/- 0.0000
# Classification accuracy based on highest probability labels:
# Accuracy: 0.9887
# Classification BSR based on highest probability labels:
# BSR: 0.9908

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 8 iterations
#
# Final cluster distortion: 0.4932
# Cluster purity calculations:
# Average cluster purity: 0.9891 +/- 0.0006
# Classification accuracy based on highest probability labels:
# Accuracy: 0.9586
# Classification BSR based on highest probability labels:
# BSR: 0.9891

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 53 iterations
#
# Final cluster distortion: 0.4516
# Cluster purity calculations:
# Average cluster purity: 0.9964 +/- 0.0000
# Classification accuracy based on highest probability labels:
# Accuracy: 0.9925
# Classification BSR based on highest probability labels:
# BSR: 0.9964

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)
