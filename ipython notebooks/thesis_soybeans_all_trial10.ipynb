# %%
import numpy as np
import scipy as sp
import distances
import gr_kmeans
import gr_lbg
import matplotlib.pyplot as plt
import plots
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from subspaces import make_subspaces

# %%
data, labels = load_ip_data([10, 11, 12], sample_size = 10000)
# Out:
# Class 10 name: Soybean-notill
# Sample number for class 10 reduced to 972
# Class 11 name: Soybean-mintill
# Sample number for class 11 reduced to 2455
# Class 12 name: Soybean-clean
# Sample number for class 12 reduced to 593

# %% [markdown]
# ### Gr(5, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=5)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.title('Embedded Data')
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1470.7714
# Cluster purity calculations:
# Average cluster purity: 0.7500 +/- 0.0422
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6127
# Classification BSR based on highest probability labels:
# BSR: 0.7500

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 15 iterations
#
# Final cluster distortion: 1425.6185
# Cluster purity calculations:
# Average cluster purity: 0.6490 +/- 0.0117
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6339
# Classification BSR based on highest probability labels:
# BSR: 0.6490

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1421.7527
# Cluster purity calculations:
# Average cluster purity: 0.5914 +/- 0.0187
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6924
# Classification BSR based on highest probability labels:
# BSR: 0.5914

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 26 iterations
#
# Final cluster distortion: 1360.2683
# Cluster purity calculations:
# Average cluster purity: 0.6753 +/- 0.0216
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6812
# Classification BSR based on highest probability labels:
# BSR: 0.6753

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1379.7279
# Cluster purity calculations:
# Average cluster purity: 0.7648 +/- 0.0335
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6824
# Classification BSR based on highest probability labels:
# BSR: 0.7648

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100)
# Out:
# LBG terminated after 25 iterations
#
# Final cluster distortion: 1330.8411
# Cluster purity calculations:
# Average cluster purity: 0.7501 +/- 0.0235
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7223
# Classification BSR based on highest probability labels:
# BSR: 0.7501

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ### Gr(10, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=10)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1520.2812
# Cluster purity calculations:
# Average cluster purity: 0.8713 +/- 0.0331
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6160
# Classification BSR based on highest probability labels:
# BSR: 0.8713

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 11 iterations
#
# Final cluster distortion: 1407.9349
# Cluster purity calculations:
# Average cluster purity: 0.7567 +/- 0.0198
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7681
# Classification BSR based on highest probability labels:
# BSR: 0.7567

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1467.7860
# Cluster purity calculations:
# Average cluster purity: 0.8982 +/- 0.0361
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6160
# Classification BSR based on highest probability labels:
# BSR: 0.8982

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 7 iterations
#
# Final cluster distortion: 1372.6783
# Cluster purity calculations:
# Average cluster purity: 0.8238 +/- 0.0143
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8554
# Classification BSR based on highest probability labels:
# BSR: 0.8238

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1413.7938
# Cluster purity calculations:
# Average cluster purity: 0.8675 +/- 0.0404
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7032
# Classification BSR based on highest probability labels:
# BSR: 0.8675

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100)
# Out:
# LBG terminated after 8 iterations
#
# Final cluster distortion: 1331.9511
# Cluster purity calculations:
# Average cluster purity: 0.7814 +/- 0.0389
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7955
# Classification BSR based on highest probability labels:
# BSR: 0.7814

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ### Gr(15,200)

# %%
sub, lbls = make_subspaces(data, labels, dim=15)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1411.1774
# Cluster purity calculations:
# Average cluster purity: 0.8826 +/- 0.0168
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7368
# Classification BSR based on highest probability labels:
# BSR: 0.8826

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 9 iterations
#
# Final cluster distortion: 1346.1871
# Cluster purity calculations:
# Average cluster purity: 0.6528 +/- 0.0592
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6128
# Classification BSR based on highest probability labels:
# BSR: 0.6528

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1387.5750
# Cluster purity calculations:
# Average cluster purity: 0.9146 +/- 0.0194
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7820
# Classification BSR based on highest probability labels:
# BSR: 0.9146

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 11 iterations
#
# Final cluster distortion: 1289.4239
# Cluster purity calculations:
# Average cluster purity: 0.8636 +/- 0.0132
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8872
# Classification BSR based on highest probability labels:
# BSR: 0.8636

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)
