# %%
import numpy as np
import scipy as sp
import distances
import gr_kmeans
import gr_lbg
import matplotlib.pyplot as plt
import plots
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from subspaces import make_subspaces

# %%
data, labels = load_ip_data([10, 11, 12], sample_size = 10000)
# Out:
# Class 10 name: Soybean-notill
# Sample number for class 10 reduced to 972
# Class 11 name: Soybean-mintill
# Sample number for class 11 reduced to 2455
# Class 12 name: Soybean-clean
# Sample number for class 12 reduced to 593

# %% [markdown]
# ### Gr(5, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=5)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.title('Embedded Data')
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1436.0315
# Cluster purity calculations:
# Average cluster purity: 0.6620 +/- 0.0147
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6438
# Classification BSR based on highest probability labels:
# BSR: 0.6620

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 10 iterations
#
# Final cluster distortion: 1429.3857
# Cluster purity calculations:
# Average cluster purity: 0.6617 +/- 0.0047
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6812
# Classification BSR based on highest probability labels:
# BSR: 0.6617

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1405.3713
# Cluster purity calculations:
# Average cluster purity: 0.7489 +/- 0.0382
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6675
# Classification BSR based on highest probability labels:
# BSR: 0.7489

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 22 iterations
#
# Final cluster distortion: 1362.9609
# Cluster purity calculations:
# Average cluster purity: 0.7242 +/- 0.0167
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7148
# Classification BSR based on highest probability labels:
# BSR: 0.7242

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1385.9592
# Cluster purity calculations:
# Average cluster purity: 0.7157 +/- 0.0319
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6887
# Classification BSR based on highest probability labels:
# BSR: 0.7157

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100)
# Out:
# LBG terminated after 19 iterations
#
# Final cluster distortion: 1318.0080
# Cluster purity calculations:
# Average cluster purity: 0.7405 +/- 0.0154
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7410
# Classification BSR based on highest probability labels:
# BSR: 0.7405

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ### Gr(10, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=10)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1518.1093
# Cluster purity calculations:
# Average cluster purity: 0.7037 +/- 0.0460
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6110
# Classification BSR based on highest probability labels:
# BSR: 0.7037

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 13 iterations
#
# Final cluster distortion: 1408.0128
# Cluster purity calculations:
# Average cluster purity: 0.7621 +/- 0.0207
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7681
# Classification BSR based on highest probability labels:
# BSR: 0.7621

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1401.9284
# Cluster purity calculations:
# Average cluster purity: 0.8893 +/- 0.0188
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8005
# Classification BSR based on highest probability labels:
# BSR: 0.8893

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 22 iterations
#
# Final cluster distortion: 1353.0579
# Cluster purity calculations:
# Average cluster purity: 0.8336 +/- 0.0053
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8204
# Classification BSR based on highest probability labels:
# BSR: 0.8336

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1437.0291
# Cluster purity calculations:
# Average cluster purity: 0.9011 +/- 0.0283
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6883
# Classification BSR based on highest probability labels:
# BSR: 0.9011

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100)
# Out:
# LBG terminated after 8 iterations
#
# Final cluster distortion: 1334.5884
# Cluster purity calculations:
# Average cluster purity: 0.8866 +/- 0.0150
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8529
# Classification BSR based on highest probability labels:
# BSR: 0.8866

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ### Gr(15,200)

# %%
sub, lbls = make_subspaces(data, labels, dim=15)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1440.9998
# Cluster purity calculations:
# Average cluster purity: 0.8712 +/- 0.0332
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6165
# Classification BSR based on highest probability labels:
# BSR: 0.8712

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 9 iterations
#
# Final cluster distortion: 1338.1190
# Cluster purity calculations:
# Average cluster purity: 0.7916 +/- 0.0237
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8421
# Classification BSR based on highest probability labels:
# BSR: 0.7916

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1386.9193
# Cluster purity calculations:
# Average cluster purity: 0.9180 +/- 0.0172
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7895
# Classification BSR based on highest probability labels:
# BSR: 0.9180

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 11 iterations
#
# Final cluster distortion: 1304.4740
# Cluster purity calculations:
# Average cluster purity: 0.8953 +/- 0.0056
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8609
# Classification BSR based on highest probability labels:
# BSR: 0.8953

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)
