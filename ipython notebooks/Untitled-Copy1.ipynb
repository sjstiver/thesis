# %%
import numpy as np
import scipy as sp
import distances
import gr_kmeans
import gr_lbg
import matplotlib.pyplot as plt
import plots
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from subspaces import make_subspaces

# %%
data, labels = load_ip_data([10, 11, 12], sample_size = 10000)
# Out:
# Class 10 name: Soybean-notill
# Sample number for class 10 reduced to 972
# Class 11 name: Soybean-mintill
# Sample number for class 11 reduced to 2455
# Class 12 name: Soybean-clean
# Sample number for class 12 reduced to 593

# %%
sub, lbls = make_subspaces(data, labels, dim=5)

# %%
print(data.shape)
# Out:
# (200, 4020)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %%
lbg = gr_lbg.gr_lbg()
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# Iteration 1 cluster distortion: 1.87249717
# Iteration 2 cluster distortion: 1.81816877
# Iteration 3 cluster distortion: 1.80117208
# Iteration 4 cluster distortion: 1.79583356
# Iteration 5 cluster distortion: 1.79307877
# Iteration 6 cluster distortion: 1.79345932
# Iteration 7 cluster distortion: 1.79201333
# Iteration 8 cluster distortion: 1.79219826
# Iteration 9 cluster distortion: 1.79117281
# Iteration 10 cluster distortion: 1.79191203
# Iteration 11 cluster distortion: 1.79157424
# Iteration 12 cluster distortion: 1.79129527
# Iteration 13 cluster distortion: 1.79066639
# Iteration 14 cluster distortion: 1.78970556
# Iteration 15 cluster distortion: 1.78963707
# Iteration 16 cluster distortion: 1.78963707
# LBG terminated after 16 iterations

# %%
kmeans = gr_kmeans.gr_kmeans()
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, show_cluster_data=True, numits=10)
# Out:
# Epoch 1 cluster distortion: 1.90867154
# Epoch 2 cluster distortion: 1.88193132
# Epoch 3 cluster distortion: 1.87224012
# Epoch 4 cluster distortion: 1.86320981
# Epoch 5 cluster distortion: 1.85931806
# Epoch 6 cluster distortion: 1.85396375
# Epoch 7 cluster distortion: 1.85144911
# Epoch 8 cluster distortion: 1.84942622
# Epoch 9 cluster distortion: 1.84844821
# Epoch 10 cluster distortion: 1.84822737
# Kmeans terminated after 10 iterations

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %%
lbg = gr_lbg.gr_lbg(numits=100)
lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True)
# Out:
# LBG terminated after 46 iterations

# %%
lbg = gr_lbg.gr_lbg(numits=100)
lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True)
# Out:
# LBG terminated after 17 iterations

# %%
sub, lbls = make_subspaces(data, labels, dim=10)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %%
lbg = gr_lbg.gr_lbg(numits=100)
lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True)
# Out:
# LBG terminated after 10 iterations

# %%
lbg = gr_lbg.gr_lbg(numits=100)
lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True)
# Out:
# LBG terminated after 15 iterations

# %%
sub, lbls = make_subspaces(data, labels, dim=15)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %%
lbg = gr_lbg.gr_lbg(numits=100)
lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True)
# Out:
# LBG terminated after 12 iterations

# %%
lbg = gr_lbg.gr_lbg(numits=100)
lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True)
# Out:
# LBG terminated after 10 iterations
