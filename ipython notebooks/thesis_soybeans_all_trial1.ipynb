# %%
import numpy as np
import scipy as sp
import distances
import gr_kmeans
import gr_lbg
import matplotlib.pyplot as plt
import plots
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from subspaces import make_subspaces

# %%
data, labels = load_ip_data([10, 11, 12], sample_size = 10000)
# Out:
# Class 10 name: Soybean-notill
# Sample number for class 10 reduced to 972
# Class 11 name: Soybean-mintill
# Sample number for class 11 reduced to 2455
# Class 12 name: Soybean-clean
# Sample number for class 12 reduced to 593

# %% [markdown]
# ### Gr(5, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=5)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.title('Embedded Data')
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1438.0354
# Cluster purity calculations:
# Average cluster purity: 0.6824 +/- 0.0213
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6438
# Classification BSR based on highest probability labels:
# BSR: 0.6824

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 14 iterations
#
# Final cluster distortion: 1425.6014
# Cluster purity calculations:
# Average cluster purity: 0.6536 +/- 0.0125
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6364
# Classification BSR based on highest probability labels:
# BSR: 0.6536

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1398.1410
# Cluster purity calculations:
# Average cluster purity: 0.7103 +/- 0.0396
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6737
# Classification BSR based on highest probability labels:
# BSR: 0.7103

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 19 iterations
#
# Final cluster distortion: 1359.9948
# Cluster purity calculations:
# Average cluster purity: 0.7028 +/- 0.0142
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7036
# Classification BSR based on highest probability labels:
# BSR: 0.7028

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1390.2651
# Cluster purity calculations:
# Average cluster purity: 0.7341 +/- 0.0453
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7011
# Classification BSR based on highest probability labels:
# BSR: 0.7341

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100)
# Out:
# LBG terminated after 20 iterations
#
# Final cluster distortion: 1319.0140
# Cluster purity calculations:
# Average cluster purity: 0.7013 +/- 0.0254
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6887
# Classification BSR based on highest probability labels:
# BSR: 0.7013

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ### Gr(10, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=10)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1465.2064
# Cluster purity calculations:
# Average cluster purity: 0.7737 +/- 0.0483
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6908
# Classification BSR based on highest probability labels:
# BSR: 0.7737

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 8 iterations
#
# Final cluster distortion: 1408.0769
# Cluster purity calculations:
# Average cluster purity: 0.7802 +/- 0.0229
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7756
# Classification BSR based on highest probability labels:
# BSR: 0.7802

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1456.2195
# Cluster purity calculations:
# Average cluster purity: 0.9059 +/- 0.0181
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7157
# Classification BSR based on highest probability labels:
# BSR: 0.9059

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 12 iterations
#
# Final cluster distortion: 1365.6857
# Cluster purity calculations:
# Average cluster purity: 0.8416 +/- 0.0079
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8454
# Classification BSR based on highest probability labels:
# BSR: 0.8416

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1408.4508
# Cluster purity calculations:
# Average cluster purity: 0.9372 +/- 0.0209
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7706
# Classification BSR based on highest probability labels:
# BSR: 0.9372

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100)
# Out:
# LBG terminated after 31 iterations
#
# Final cluster distortion: 1336.9882
# Cluster purity calculations:
# Average cluster purity: 0.8585 +/- 0.0082
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8579
# Classification BSR based on highest probability labels:
# BSR: 0.8585

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ### Gr(15,200)

# %%
sub, lbls = make_subspaces(data, labels, dim=15)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1440.5887
# Cluster purity calculations:
# Average cluster purity: 0.8695 +/- 0.0341
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6128
# Classification BSR based on highest probability labels:
# BSR: 0.8695

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 15 iterations
#
# Final cluster distortion: 1341.4630
# Cluster purity calculations:
# Average cluster purity: 0.7553 +/- 0.0276
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7632
# Classification BSR based on highest probability labels:
# BSR: 0.7553

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1386.8010
# Cluster purity calculations:
# Average cluster purity: 0.9459 +/- 0.0117
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7444
# Classification BSR based on highest probability labels:
# BSR: 0.9459

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 6 iterations
#
# Final cluster distortion: 1293.6363
# Cluster purity calculations:
# Average cluster purity: 0.8300 +/- 0.0136
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8609
# Classification BSR based on highest probability labels:
# BSR: 0.8300

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)
