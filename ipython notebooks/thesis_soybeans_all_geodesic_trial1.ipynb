# %%
# changed kmeans distortion to calculate delta every iteration instead of every epoch

import numpy as np
import scipy as sp
import distances
import gr_kmeans
import gr_lbg
import matplotlib.pyplot as plt
import plots
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from subspaces import make_subspaces

# %%
data, labels = load_ip_data([10, 11, 12], sample_size = 10000)
# Out:
# Class 10 name: Soybean-notill
# Sample number for class 10 reduced to 972
# Class 11 name: Soybean-mintill
# Sample number for class 11 reduced to 2455
# Class 12 name: Soybean-clean
# Sample number for class 12 reduced to 593

# %% [markdown]
# ### Gr(5, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=5)

# %%
dist_metric = 'geodesic'
D = distances.geodesic_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.title('Embedded Data')
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2305.2178
# Cluster purity calculations:
# Average cluster purity: 0.6406 +/- 0.0188
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6115
# Classification BSR based on highest probability labels:
# BSR: 0.6406

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100, 
                                  dist_metric=dist_metric)
# Out:
# LBG terminated after 12 iterations
#
# Final cluster distortion: 2257.5361
# Cluster purity calculations:
# Average cluster purity: 0.6208 +/- 0.0113
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6115
# Classification BSR based on highest probability labels:
# BSR: 0.6208

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2124.2236
# Cluster purity calculations:
# Average cluster purity: 0.6771 +/- 0.0258
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6800
# Classification BSR based on highest probability labels:
# BSR: 0.6771

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100, 
                                  dist_metric=dist_metric)
# Out:
# LBG terminated after 30 iterations
#
# Final cluster distortion: 2081.9628
# Cluster purity calculations:
# Average cluster purity: 0.6930 +/- 0.0136
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6725
# Classification BSR based on highest probability labels:
# BSR: 0.6930

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2007.2148
# Cluster purity calculations:
# Average cluster purity: 0.6786 +/- 0.0213
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6999
# Classification BSR based on highest probability labels:
# BSR: 0.6786

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 18 iterations
#
# Final cluster distortion: 2001.9956
# Cluster purity calculations:
# Average cluster purity: 0.7053 +/- 0.0114
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7161
# Classification BSR based on highest probability labels:
# BSR: 0.7053

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ### Gr(10, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=10)

# %%
D = distances.geodesic_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2366.9144
# Cluster purity calculations:
# Average cluster purity: 0.7756 +/- 0.0042
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7581
# Classification BSR based on highest probability labels:
# BSR: 0.7756

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 9 iterations
#
# Final cluster distortion: 2315.1588
# Cluster purity calculations:
# Average cluster purity: 0.6824 +/- 0.0279
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7082
# Classification BSR based on highest probability labels:
# BSR: 0.6824

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2292.4547
# Cluster purity calculations:
# Average cluster purity: 0.7794 +/- 0.0329
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6708
# Classification BSR based on highest probability labels:
# BSR: 0.7794

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 9 iterations
#
# Final cluster distortion: 2208.4800
# Cluster purity calculations:
# Average cluster purity: 0.7652 +/- 0.0200
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7980
# Classification BSR based on highest probability labels:
# BSR: 0.7652

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2186.9106
# Cluster purity calculations:
# Average cluster purity: 0.8322 +/- 0.0321
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7307
# Classification BSR based on highest probability labels:
# BSR: 0.8322

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 8 iterations
#
# Final cluster distortion: 2132.1152
# Cluster purity calculations:
# Average cluster purity: 0.8100 +/- 0.0146
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7880
# Classification BSR based on highest probability labels:
# BSR: 0.8100

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ### Gr(15,200)

# %%
sub, lbls = make_subspaces(data, labels, dim=15)

# %%
D = distances.geodesic_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2286.7002
# Cluster purity calculations:
# Average cluster purity: 0.8429 +/- 0.0143
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7293
# Classification BSR based on highest probability labels:
# BSR: 0.8429

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 7 iterations
#
# Final cluster distortion: 2219.5596
# Cluster purity calculations:
# Average cluster purity: 0.7102 +/- 0.0402
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6955
# Classification BSR based on highest probability labels:
# BSR: 0.7102

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2194.0443
# Cluster purity calculations:
# Average cluster purity: 0.8374 +/- 0.0487
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6955
# Classification BSR based on highest probability labels:
# BSR: 0.8374

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 14 iterations
#
# Final cluster distortion: 2117.4203
# Cluster purity calculations:
# Average cluster purity: 0.7463 +/- 0.0306
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8083
# Classification BSR based on highest probability labels:
# BSR: 0.7463

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)
