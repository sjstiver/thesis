# %%
import numpy as np
import scipy as sp
import distances
import gr_kmeans
import gr_lbg
import plots
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from mnist import load_mnist_data
from subspaces import make_subspaces

# %%
data, labels = load_mnist_data([0, 1], sample_size = 500)

# %% [markdown]
# ## Gr(5, 500)

# %%
sub, lbls = make_subspaces(data, labels, dim=5)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 2 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=2, plot_results=True, eigplot=True,
                                          show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, center_count=2, plot_results=True, eigplot=True,
                                 show_cluster_data=True, numits=100)
# Out:
# LBG terminated after 2 iterations

# %%
fig, ax = plt.subplots()
im = ax.imshow(lbg_centers[0][:,0].reshape((28,28)))

# %%
fig, ax = plt.subplots()
im = ax.imshow(lbg_centers[1][:,0].reshape((28,28)))

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 4 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=4, plot_results=True, eigplot=True,
                                          show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 84 iterations

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, center_count=4, plot_results=True, eigplot=True,
                                 show_cluster_data=True, numits=100)
# Out:
# LBG terminated after 6 iterations

# %%
fig, ax = plt.subplots()
im = ax.imshow(lbg_centers[0][:,0].reshape((28,28)))

# %%
fig, ax = plt.subplots()
im = ax.imshow(lbg_centers[1][:,0].reshape((28,28)))

# %%
fig, ax = plt.subplots()
im = ax.imshow(lbg_centers[2][:,0].reshape((28,28)))

# %%
fig, ax = plt.subplots()
im = ax.imshow(lbg_centers[3][:,0].reshape((28,28)))

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ## Gr(10, 500)

# %%
sub, lbls = make_subspaces(data, labels, dim=10)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 2 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=2, plot_results=True, eigplot=True,
                                          show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 74 iterations

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, center_count=2, plot_results=True, eigplot=True,
                                 show_cluster_data=True, numits=100)
# Out:
# LBG terminated after 2 iterations

# %%
fig, ax = plt.subplots()
im = ax.imshow(lbg_centers[0][:,0].reshape((28,28)))

# %%
fig, ax = plt.subplots()
im = ax.imshow(lbg_centers[1][:,0].reshape((28,28)))

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 4 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=4, plot_results=True, eigplot=True,
                                          show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 74 iterations

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, center_count=4, plot_results=True, eigplot=True,
                                 show_cluster_data=True, numits=100)
# Out:
# LBG terminated after 2 iterations

# %%
fig, ax = plt.subplots()
im = ax.imshow(lbg_centers[0][:,0].reshape((28,28)))

# %%
fig, ax = plt.subplots()
im = ax.imshow(lbg_centers[1][:,0].reshape((28,28)))

# %%
fig, ax = plt.subplots()
im = ax.imshow(lbg_centers[2][:,0].reshape((28,28)))

# %%
fig, ax = plt.subplots()
im = ax.imshow(lbg_centers[3][:,0].reshape((28,28)))

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)
