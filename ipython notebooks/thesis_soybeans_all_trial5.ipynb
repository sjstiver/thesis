# %%
import numpy as np
import scipy as sp
import distances
import gr_kmeans
import gr_lbg
import matplotlib.pyplot as plt
import plots
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from subspaces import make_subspaces

# %%
data, labels = load_ip_data([10, 11, 12], sample_size = 10000)
# Out:
# Class 10 name: Soybean-notill
# Sample number for class 10 reduced to 972
# Class 11 name: Soybean-mintill
# Sample number for class 11 reduced to 2455
# Class 12 name: Soybean-clean
# Sample number for class 12 reduced to 593

# %% [markdown]
# ### Gr(5, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=5)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.title('Embedded Data')
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1437.0094
# Cluster purity calculations:
# Average cluster purity: 0.6631 +/- 0.0133
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6501
# Classification BSR based on highest probability labels:
# BSR: 0.6631

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 10 iterations
#
# Final cluster distortion: 1429.8291
# Cluster purity calculations:
# Average cluster purity: 0.6750 +/- 0.0278
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6389
# Classification BSR based on highest probability labels:
# BSR: 0.6750

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1426.9452
# Cluster purity calculations:
# Average cluster purity: 0.7917 +/- 0.0276
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7061
# Classification BSR based on highest probability labels:
# BSR: 0.7917

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 14 iterations
#
# Final cluster distortion: 1360.2785
# Cluster purity calculations:
# Average cluster purity: 0.6932 +/- 0.0199
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6750
# Classification BSR based on highest probability labels:
# BSR: 0.6932

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1393.6899
# Cluster purity calculations:
# Average cluster purity: 0.6889 +/- 0.0551
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6899
# Classification BSR based on highest probability labels:
# BSR: 0.6889

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100)
# Out:
# LBG terminated after 12 iterations
#
# Final cluster distortion: 1335.2949
# Cluster purity calculations:
# Average cluster purity: 0.7509 +/- 0.0240
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7086
# Classification BSR based on highest probability labels:
# BSR: 0.7509

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ### Gr(10, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=10)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1466.2531
# Cluster purity calculations:
# Average cluster purity: 0.7708 +/- 0.0479
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6858
# Classification BSR based on highest probability labels:
# BSR: 0.7708

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 8 iterations
#
# Final cluster distortion: 1407.9465
# Cluster purity calculations:
# Average cluster purity: 0.7652 +/- 0.0219
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7681
# Classification BSR based on highest probability labels:
# BSR: 0.7652

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1423.0257
# Cluster purity calculations:
# Average cluster purity: 0.8879 +/- 0.0283
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7556
# Classification BSR based on highest probability labels:
# BSR: 0.8879

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 8 iterations
#
# Final cluster distortion: 1365.2636
# Cluster purity calculations:
# Average cluster purity: 0.8779 +/- 0.0043
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8603
# Classification BSR based on highest probability labels:
# BSR: 0.8779

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1412.8468
# Cluster purity calculations:
# Average cluster purity: 0.8826 +/- 0.0375
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7830
# Classification BSR based on highest probability labels:
# BSR: 0.8826

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100)
# Out:
# LBG terminated after 10 iterations
#
# Final cluster distortion: 1341.3491
# Cluster purity calculations:
# Average cluster purity: 0.8268 +/- 0.0253
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8329
# Classification BSR based on highest probability labels:
# BSR: 0.8268

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ### Gr(15,200)

# %%
sub, lbls = make_subspaces(data, labels, dim=15)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1404.1598
# Cluster purity calculations:
# Average cluster purity: 0.8306 +/- 0.0232
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7820
# Classification BSR based on highest probability labels:
# BSR: 0.8306

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 10 iterations
#
# Final cluster distortion: 1339.8049
# Cluster purity calculations:
# Average cluster purity: 0.7665 +/- 0.0388
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7744
# Classification BSR based on highest probability labels:
# BSR: 0.7665

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1425.8099
# Cluster purity calculations:
# Average cluster purity: 0.9342 +/- 0.0216
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6128
# Classification BSR based on highest probability labels:
# BSR: 0.9342

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 9 iterations
#
# Final cluster distortion: 1310.7075
# Cluster purity calculations:
# Average cluster purity: 0.7951 +/- 0.0317
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7331
# Classification BSR based on highest probability labels:
# BSR: 0.7951

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)
