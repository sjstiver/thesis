# %%
# changed kmeans distortion to calculate delta every iteration instead of every epoch

import numpy as np
import scipy as sp
import distances
import gr_kmeans
import gr_lbg
import matplotlib.pyplot as plt
import plots
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from subspaces import make_subspaces

# %%
data, labels = load_ip_data([10, 11, 12], sample_size = 10000)
# Out:
# Class 10 name: Soybean-notill
# Sample number for class 10 reduced to 972
# Class 11 name: Soybean-mintill
# Sample number for class 11 reduced to 2455
# Class 12 name: Soybean-clean
# Sample number for class 12 reduced to 593

# %% [markdown]
# ### Gr(5, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=5)

# %%
dist_metric = 'geodesic'
D = distances.geodesic_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.title('Embedded Data')
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2305.2178
# Cluster purity calculations:
# Average cluster purity: 0.6406 +/- 0.0188
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6115
# Classification BSR based on highest probability labels:
# BSR: 0.6406

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100, 
                                  dist_metric=dist_metric)
# Out:
# LBG terminated after 7 iterations
#
# Final cluster distortion: 2257.6669
# Cluster purity calculations:
# Average cluster purity: 0.6194 +/- 0.0112
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6115
# Classification BSR based on highest probability labels:
# BSR: 0.6194

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2117.1446
# Cluster purity calculations:
# Average cluster purity: 0.6539 +/- 0.0215
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6800
# Classification BSR based on highest probability labels:
# BSR: 0.6539

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100, 
                                  dist_metric=dist_metric)
# Out:
# LBG terminated after 37 iterations
#
# Final cluster distortion: 2081.5730
# Cluster purity calculations:
# Average cluster purity: 0.6811 +/- 0.0117
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6800
# Classification BSR based on highest probability labels:
# BSR: 0.6811

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2056.0346
# Cluster purity calculations:
# Average cluster purity: 0.7044 +/- 0.0253
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6800
# Classification BSR based on highest probability labels:
# BSR: 0.7044

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 16 iterations
#
# Final cluster distortion: 2016.5131
# Cluster purity calculations:
# Average cluster purity: 0.6834 +/- 0.0144
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6899
# Classification BSR based on highest probability labels:
# BSR: 0.6834

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ### Gr(10, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=10)

# %%
D = distances.geodesic_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2320.7121
# Cluster purity calculations:
# Average cluster purity: 0.7044 +/- 0.0234
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7232
# Classification BSR based on highest probability labels:
# BSR: 0.7044

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 11 iterations
#
# Final cluster distortion: 2335.5512
# Cluster purity calculations:
# Average cluster purity: 0.7141 +/- 0.0346
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6708
# Classification BSR based on highest probability labels:
# BSR: 0.7141

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2265.1343
# Cluster purity calculations:
# Average cluster purity: 0.8541 +/- 0.0251
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7631
# Classification BSR based on highest probability labels:
# BSR: 0.8541

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 10 iterations
#
# Final cluster distortion: 2205.1065
# Cluster purity calculations:
# Average cluster purity: 0.7800 +/- 0.0240
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7980
# Classification BSR based on highest probability labels:
# BSR: 0.7800

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2223.4992
# Cluster purity calculations:
# Average cluster purity: 0.9092 +/- 0.0196
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7805
# Classification BSR based on highest probability labels:
# BSR: 0.9092

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 12 iterations
#
# Final cluster distortion: 2117.9731
# Cluster purity calculations:
# Average cluster purity: 0.8037 +/- 0.0168
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7905
# Classification BSR based on highest probability labels:
# BSR: 0.8037

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ### Gr(15,200)

# %%
sub, lbls = make_subspaces(data, labels, dim=15)

# %%
D = distances.geodesic_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2291.0265
# Cluster purity calculations:
# Average cluster purity: 0.8309 +/- 0.0146
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7331
# Classification BSR based on highest probability labels:
# BSR: 0.8309

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 7 iterations
#
# Final cluster distortion: 2226.8264
# Cluster purity calculations:
# Average cluster purity: 0.7445 +/- 0.0247
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7406
# Classification BSR based on highest probability labels:
# BSR: 0.7445

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2197.0092
# Cluster purity calculations:
# Average cluster purity: 0.8343 +/- 0.0533
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6992
# Classification BSR based on highest probability labels:
# BSR: 0.8343

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 10 iterations
#
# Final cluster distortion: 2113.2424
# Cluster purity calculations:
# Average cluster purity: 0.7973 +/- 0.0167
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8120
# Classification BSR based on highest probability labels:
# BSR: 0.7973

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)
