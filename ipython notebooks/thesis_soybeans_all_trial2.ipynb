# %%
import numpy as np
import scipy as sp
import distances
import gr_kmeans
import gr_lbg
import matplotlib.pyplot as plt
import plots
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from subspaces import make_subspaces

# %%
data, labels = load_ip_data([10, 11, 12], sample_size = 10000)
# Out:
# Class 10 name: Soybean-notill
# Sample number for class 10 reduced to 972
# Class 11 name: Soybean-mintill
# Sample number for class 11 reduced to 2455
# Class 12 name: Soybean-clean
# Sample number for class 12 reduced to 593

# %% [markdown]
# ### Gr(5, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=5)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.title('Embedded Data')
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1461.0638
# Cluster purity calculations:
# Average cluster purity: 0.6644 +/- 0.0046
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6775
# Classification BSR based on highest probability labels:
# BSR: 0.6644

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 10 iterations
#
# Final cluster distortion: 1437.5277
# Cluster purity calculations:
# Average cluster purity: 0.5937 +/- 0.0189
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6389
# Classification BSR based on highest probability labels:
# BSR: 0.5937

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1407.7026
# Cluster purity calculations:
# Average cluster purity: 0.7632 +/- 0.0452
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6513
# Classification BSR based on highest probability labels:
# BSR: 0.7632

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 13 iterations
#
# Final cluster distortion: 1356.6033
# Cluster purity calculations:
# Average cluster purity: 0.6637 +/- 0.0186
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6687
# Classification BSR based on highest probability labels:
# BSR: 0.6637

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1379.5146
# Cluster purity calculations:
# Average cluster purity: 0.8110 +/- 0.0233
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6961
# Classification BSR based on highest probability labels:
# BSR: 0.8110

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100)
# Out:
# LBG terminated after 16 iterations
#
# Final cluster distortion: 1330.6043
# Cluster purity calculations:
# Average cluster purity: 0.7449 +/- 0.0220
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7123
# Classification BSR based on highest probability labels:
# BSR: 0.7449

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ### Gr(10, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=10)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1465.1234
# Cluster purity calculations:
# Average cluster purity: 0.7657 +/- 0.0513
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6758
# Classification BSR based on highest probability labels:
# BSR: 0.7657

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 11 iterations
#
# Final cluster distortion: 1407.9687
# Cluster purity calculations:
# Average cluster purity: 0.7815 +/- 0.0241
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7805
# Classification BSR based on highest probability labels:
# BSR: 0.7815

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1420.3937
# Cluster purity calculations:
# Average cluster purity: 0.8970 +/- 0.0279
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7656
# Classification BSR based on highest probability labels:
# BSR: 0.8970

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 10 iterations
#
# Final cluster distortion: 1356.1352
# Cluster purity calculations:
# Average cluster purity: 0.8491 +/- 0.0126
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8454
# Classification BSR based on highest probability labels:
# BSR: 0.8491

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1431.4240
# Cluster purity calculations:
# Average cluster purity: 0.9214 +/- 0.0295
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6708
# Classification BSR based on highest probability labels:
# BSR: 0.9214

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100)
# Out:
# LBG terminated after 9 iterations
#
# Final cluster distortion: 1335.3662
# Cluster purity calculations:
# Average cluster purity: 0.8516 +/- 0.0167
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8204
# Classification BSR based on highest probability labels:
# BSR: 0.8516

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ### Gr(15,200)

# %%
sub, lbls = make_subspaces(data, labels, dim=15)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1404.8073
# Cluster purity calculations:
# Average cluster purity: 0.8346 +/- 0.0223
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7857
# Classification BSR based on highest probability labels:
# BSR: 0.8346

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 6 iterations
#
# Final cluster distortion: 1358.3313
# Cluster purity calculations:
# Average cluster purity: 0.5453 +/- 0.0373
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6128
# Classification BSR based on highest probability labels:
# BSR: 0.5453

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1384.4124
# Cluster purity calculations:
# Average cluster purity: 0.9296 +/- 0.0100
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7820
# Classification BSR based on highest probability labels:
# BSR: 0.9296

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 13 iterations
#
# Final cluster distortion: 1305.2627
# Cluster purity calculations:
# Average cluster purity: 0.7977 +/- 0.0213
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8233
# Classification BSR based on highest probability labels:
# BSR: 0.7977

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)
