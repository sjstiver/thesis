# %%
import numpy as np
import scipy as sp
import distances
import gr_kmeans
import gr_lbg
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from subspaces import make_subspaces

# %%
data, labels = load_ip_data([10, 11, 12], sample_size = 10000)
# Out:
# Class  10 name: Soybean-notill
# Sample number for class 10 reduced to 972
# Class  11 name: Soybean-mintill
# Sample number for class 11 reduced to 2455
# Class  12 name: Soybean-clean
# Sample number for class 12 reduced to 593

# %%
sub, lbls = make_subspaces(data, labels, dim=5)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %%
kmeans = gr_kmeans.gr_kmeans(numits=100)
kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, show_cluster_data=True)
# Out:
# Epoch 1 cluster distortion: 1.51762410
# Epoch 2 cluster distortion: 1.49515588
# Epoch 3 cluster distortion: 1.48738615
# Epoch 4 cluster distortion: 1.47956880
# Epoch 5 cluster distortion: 1.47567801
# Epoch 6 cluster distortion: 1.47402764
# Epoch 7 cluster distortion: 1.47078906
# Epoch 8 cluster distortion: 1.46935644
# Epoch 9 cluster distortion: 1.46578254
# Epoch 10 cluster distortion: 1.46671455
# Kmeans terminated after 10 iterations

# %%
kmeans = gr_kmeans.gr_kmeans(numits=100)
kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, show_cluster_data=True)
# Out:
# Epoch 1 cluster distortion: 1.44392229
# Epoch 2 cluster distortion: 1.42654054
# Epoch 3 cluster distortion: 1.42192440
# Epoch 4 cluster distortion: 1.41702027
# Epoch 5 cluster distortion: 1.41419576
# Epoch 6 cluster distortion: 1.41151778
# Epoch 7 cluster distortion: 1.41210677
# Kmeans terminated after 7 iterations

# %%
kmeans = gr_kmeans.gr_kmeans(numits=100)
kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, show_cluster_data=True)
# Out:
# Epoch 1 cluster distortion: 1.31930409
# Epoch 2 cluster distortion: 1.29287378
# Epoch 3 cluster distortion: 1.28911350
# Epoch 4 cluster distortion: 1.28276875
# Epoch 5 cluster distortion: 1.27926214
# Epoch 6 cluster distortion: 1.27897746
# Epoch 7 cluster distortion: 1.27801733
# Epoch 8 cluster distortion: 1.27588820
# Epoch 9 cluster distortion: 1.27409621
# Epoch 10 cluster distortion: 1.27642862
# Kmeans terminated after 10 iterations

# %%
lbg = gr_lbg.gr_lbg(numits=100)
lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True)
# Out:
# LBG terminated after 15 iterations

# %%
lbg = gr_lbg.gr_lbg(numits=100)
lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True)
# Out:
# LBG terminated after 46 iterations

# %%
lbg = gr_lbg.gr_lbg(numits=100)
lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True)
# Out:
# LBG terminated after 17 iterations

# %%
sub, lbls = make_subspaces(data, labels, dim=10)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %%
kmeans = gr_kmeans.gr_kmeans(numits=100)
kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, show_cluster_data=True)
# Out:
# Epoch 1 cluster distortion: 1.53181034
# Epoch 2 cluster distortion: 1.50254129
# Epoch 3 cluster distortion: 1.49099635
# Epoch 4 cluster distortion: 1.48504018
# Epoch 5 cluster distortion: 1.48031530
# Epoch 6 cluster distortion: 1.47763710
# Epoch 7 cluster distortion: 1.47612174
# Epoch 8 cluster distortion: 1.47503271
# Epoch 9 cluster distortion: 1.47466411
# Epoch 10 cluster distortion: 1.47388122
# Epoch 11 cluster distortion: 1.47338503
# Epoch 12 cluster distortion: 1.47461803
# Kmeans terminated after 12 iterations

# %%
kmeans = gr_kmeans.gr_kmeans(numits=100)
kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, show_cluster_data=True)
# Out:
# Epoch 1 cluster distortion: 1.39416153
# Epoch 2 cluster distortion: 1.38580357
# Epoch 3 cluster distortion: 1.38097846
# Epoch 4 cluster distortion: 1.37641268
# Epoch 5 cluster distortion: 1.37334626
# Epoch 6 cluster distortion: 1.37062514
# Epoch 7 cluster distortion: 1.37378354
# Kmeans terminated after 7 iterations

# %%
kmeans = gr_kmeans.gr_kmeans(numits=100)
kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, show_cluster_data=True)
# Out:
# Epoch 1 cluster distortion: 1.35131023
# Epoch 2 cluster distortion: 1.33563702
# Epoch 3 cluster distortion: 1.33346856
# Epoch 4 cluster distortion: 1.33045551
# Epoch 5 cluster distortion: 1.32945413
# Epoch 6 cluster distortion: 1.32805787
# Epoch 7 cluster distortion: 1.32712285
# Epoch 8 cluster distortion: 1.32649580
# Epoch 9 cluster distortion: 1.32884738
# Kmeans terminated after 9 iterations

# %%
lbg = gr_lbg.gr_lbg(numits=100)
lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True)
# Out:
# LBG terminated after 10 iterations

# %%
lbg = gr_lbg.gr_lbg(numits=100)
lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True)
# Out:
# LBG terminated after 15 iterations

# %%
sub, lbls = make_subspaces(data, labels, dim=15)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %%
kmeans = gr_kmeans.gr_kmeans(numits=100)
kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, show_cluster_data=True)
# Out:
# Epoch 1 cluster distortion: 1.44084420
# Epoch 2 cluster distortion: 1.43496585
# Epoch 3 cluster distortion: 1.43178686
# Epoch 4 cluster distortion: 1.43080492
# Epoch 5 cluster distortion: 1.42943381
# Epoch 6 cluster distortion: 1.42880867
# Epoch 7 cluster distortion: 1.42872944
# Epoch 8 cluster distortion: 1.42855545
# Epoch 9 cluster distortion: 1.42820573
# Epoch 10 cluster distortion: 1.42788529
# Epoch 11 cluster distortion: 1.42770059
# Epoch 12 cluster distortion: 1.42724402
# Epoch 13 cluster distortion: 1.42711372
# Epoch 14 cluster distortion: 1.42690438
# Epoch 15 cluster distortion: 1.42720328
# Kmeans terminated after 15 iterations

# %%
kmeans = gr_kmeans.gr_kmeans(numits=100)
kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, show_cluster_data=True)
# Out:
# Epoch 1 cluster distortion: 1.35385279
# Epoch 2 cluster distortion: 1.35179072
# Epoch 3 cluster distortion: 1.34508386
# Epoch 4 cluster distortion: 1.34130117
# Epoch 5 cluster distortion: 1.33898344
# Epoch 6 cluster distortion: 1.33619756
# Epoch 7 cluster distortion: 1.33431526
# Epoch 8 cluster distortion: 1.33300933
# Epoch 9 cluster distortion: 1.33112453
# Epoch 10 cluster distortion: 1.33013012
# Epoch 11 cluster distortion: 1.32919905
# Epoch 12 cluster distortion: 1.32777691
# Epoch 13 cluster distortion: 1.32899844
# Kmeans terminated after 13 iterations

# %%
lbg = gr_lbg.gr_lbg(numits=100)
lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True)
# Out:
# LBG terminated after 12 iterations

# %%
lbg = gr_lbg.gr_lbg(numits=100)
lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True)
# Out:
# LBG terminated after 10 iterations
