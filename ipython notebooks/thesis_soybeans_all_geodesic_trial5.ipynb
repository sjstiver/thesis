# %%
# changed kmeans distortion to calculate delta every iteration instead of every epoch

import numpy as np
import scipy as sp
import distances
import gr_kmeans
import gr_lbg
import matplotlib.pyplot as plt
import plots
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from subspaces import make_subspaces

# %%
data, labels = load_ip_data([10, 11, 12], sample_size = 10000)
# Out:
# Class 10 name: Soybean-notill
# Sample number for class 10 reduced to 972
# Class 11 name: Soybean-mintill
# Sample number for class 11 reduced to 2455
# Class 12 name: Soybean-clean
# Sample number for class 12 reduced to 593

# %% [markdown]
# ### Gr(5, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=5)

# %%
dist_metric = 'geodesic'
D = distances.geodesic_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.title('Embedded Data')
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2266.2237
# Cluster purity calculations:
# Average cluster purity: 0.6143 +/- 0.0151
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6115
# Classification BSR based on highest probability labels:
# BSR: 0.6143

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100, 
                                  dist_metric=dist_metric)
# Out:
# LBG terminated after 13 iterations
#
# Final cluster distortion: 2267.9191
# Cluster purity calculations:
# Average cluster purity: 0.6399 +/- 0.0110
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6650
# Classification BSR based on highest probability labels:
# BSR: 0.6399

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2119.6771
# Cluster purity calculations:
# Average cluster purity: 0.6526 +/- 0.0103
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6712
# Classification BSR based on highest probability labels:
# BSR: 0.6526

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100, 
                                  dist_metric=dist_metric)
# Out:
# LBG terminated after 26 iterations
#
# Final cluster distortion: 2098.2451
# Cluster purity calculations:
# Average cluster purity: 0.6846 +/- 0.0154
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6687
# Classification BSR based on highest probability labels:
# BSR: 0.6846

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2017.3636
# Cluster purity calculations:
# Average cluster purity: 0.6909 +/- 0.0296
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6712
# Classification BSR based on highest probability labels:
# BSR: 0.6909

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 26 iterations
#
# Final cluster distortion: 2002.8477
# Cluster purity calculations:
# Average cluster purity: 0.7134 +/- 0.0121
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7049
# Classification BSR based on highest probability labels:
# BSR: 0.7134

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ### Gr(10, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=10)

# %%
D = distances.geodesic_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2375.6585
# Cluster purity calculations:
# Average cluster purity: 0.7672 +/- 0.0570
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6633
# Classification BSR based on highest probability labels:
# BSR: 0.7672

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 10 iterations
#
# Final cluster distortion: 2309.7592
# Cluster purity calculations:
# Average cluster purity: 0.6863 +/- 0.0242
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7207
# Classification BSR based on highest probability labels:
# BSR: 0.6863

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2256.5986
# Cluster purity calculations:
# Average cluster purity: 0.8737 +/- 0.0333
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7506
# Classification BSR based on highest probability labels:
# BSR: 0.8737

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 10 iterations
#
# Final cluster distortion: 2190.5927
# Cluster purity calculations:
# Average cluster purity: 0.7873 +/- 0.0152
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7781
# Classification BSR based on highest probability labels:
# BSR: 0.7873

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2228.1772
# Cluster purity calculations:
# Average cluster purity: 0.7833 +/- 0.0500
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6883
# Classification BSR based on highest probability labels:
# BSR: 0.7833

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 21 iterations
#
# Final cluster distortion: 2112.1324
# Cluster purity calculations:
# Average cluster purity: 0.8156 +/- 0.0139
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8130
# Classification BSR based on highest probability labels:
# BSR: 0.8156

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ### Gr(15,200)

# %%
sub, lbls = make_subspaces(data, labels, dim=15)

# %%
D = distances.geodesic_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2281.3328
# Cluster purity calculations:
# Average cluster purity: 0.7307 +/- 0.0394
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6203
# Classification BSR based on highest probability labels:
# BSR: 0.7307

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 22 iterations
#
# Final cluster distortion: 2226.6983
# Cluster purity calculations:
# Average cluster purity: 0.7393 +/- 0.0129
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7519
# Classification BSR based on highest probability labels:
# BSR: 0.7393

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2262.9444
# Cluster purity calculations:
# Average cluster purity: 0.9012 +/- 0.0279
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7331
# Classification BSR based on highest probability labels:
# BSR: 0.9012

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 14 iterations
#
# Final cluster distortion: 2105.4976
# Cluster purity calculations:
# Average cluster purity: 0.8649 +/- 0.0127
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8496
# Classification BSR based on highest probability labels:
# BSR: 0.8649

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)
