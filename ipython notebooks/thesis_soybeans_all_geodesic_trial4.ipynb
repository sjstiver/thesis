# %%
# changed kmeans distortion to calculate delta every iteration instead of every epoch

import numpy as np
import scipy as sp
import distances
import gr_kmeans
import gr_lbg
import matplotlib.pyplot as plt
import plots
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from subspaces import make_subspaces

# %%
data, labels = load_ip_data([10, 11, 12], sample_size = 10000)
# Out:
# Class 10 name: Soybean-notill
# Sample number for class 10 reduced to 972
# Class 11 name: Soybean-mintill
# Sample number for class 11 reduced to 2455
# Class 12 name: Soybean-clean
# Sample number for class 12 reduced to 593

# %% [markdown]
# ### Gr(5, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=5)

# %%
dist_metric = 'geodesic'
D = distances.geodesic_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.title('Embedded Data')
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2281.6945
# Cluster purity calculations:
# Average cluster purity: 0.6008 +/- 0.0201
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6438
# Classification BSR based on highest probability labels:
# BSR: 0.6008

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100, 
                                  dist_metric=dist_metric)
# Out:
# LBG terminated after 22 iterations
#
# Final cluster distortion: 2257.5895
# Cluster purity calculations:
# Average cluster purity: 0.6217 +/- 0.0121
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6115
# Classification BSR based on highest probability labels:
# BSR: 0.6217

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2120.5019
# Cluster purity calculations:
# Average cluster purity: 0.6498 +/- 0.0158
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6737
# Classification BSR based on highest probability labels:
# BSR: 0.6498

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100, 
                                  dist_metric=dist_metric)
# Out:
# LBG terminated after 21 iterations
#
# Final cluster distortion: 2124.6942
# Cluster purity calculations:
# Average cluster purity: 0.7296 +/- 0.0209
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6812
# Classification BSR based on highest probability labels:
# BSR: 0.7296

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2091.4231
# Cluster purity calculations:
# Average cluster purity: 0.6503 +/- 0.0402
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6737
# Classification BSR based on highest probability labels:
# BSR: 0.6503

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 29 iterations
#
# Final cluster distortion: 2005.0404
# Cluster purity calculations:
# Average cluster purity: 0.7251 +/- 0.0119
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7385
# Classification BSR based on highest probability labels:
# BSR: 0.7251

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ### Gr(10, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=10)

# %%
D = distances.geodesic_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2370.6767
# Cluster purity calculations:
# Average cluster purity: 0.7635 +/- 0.0593
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6584
# Classification BSR based on highest probability labels:
# BSR: 0.7635

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 14 iterations
#
# Final cluster distortion: 2323.1855
# Cluster purity calculations:
# Average cluster purity: 0.6626 +/- 0.0380
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6883
# Classification BSR based on highest probability labels:
# BSR: 0.6626

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2307.3553
# Cluster purity calculations:
# Average cluster purity: 0.8260 +/- 0.0454
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6808
# Classification BSR based on highest probability labels:
# BSR: 0.8260

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 22 iterations
#
# Final cluster distortion: 2186.5248
# Cluster purity calculations:
# Average cluster purity: 0.8135 +/- 0.0049
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8105
# Classification BSR based on highest probability labels:
# BSR: 0.8135

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2236.8417
# Cluster purity calculations:
# Average cluster purity: 0.7391 +/- 0.0397
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6983
# Classification BSR based on highest probability labels:
# BSR: 0.7391

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 14 iterations
#
# Final cluster distortion: 2126.3074
# Cluster purity calculations:
# Average cluster purity: 0.7838 +/- 0.0184
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7805
# Classification BSR based on highest probability labels:
# BSR: 0.7838

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ### Gr(15,200)

# %%
sub, lbls = make_subspaces(data, labels, dim=15)

# %%
D = distances.geodesic_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2277.8110
# Cluster purity calculations:
# Average cluster purity: 0.7340 +/- 0.0482
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6165
# Classification BSR based on highest probability labels:
# BSR: 0.7340

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 9 iterations
#
# Final cluster distortion: 2225.1096
# Cluster purity calculations:
# Average cluster purity: 0.7501 +/- 0.0104
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7632
# Classification BSR based on highest probability labels:
# BSR: 0.7501

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2194.7361
# Cluster purity calculations:
# Average cluster purity: 0.8383 +/- 0.0480
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6955
# Classification BSR based on highest probability labels:
# BSR: 0.8383

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 7 iterations
#
# Final cluster distortion: 2116.7699
# Cluster purity calculations:
# Average cluster purity: 0.8707 +/- 0.0104
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8496
# Classification BSR based on highest probability labels:
# BSR: 0.8707

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)
