# %%
import numpy as np
import scipy as sp
import distances
import kmeans
import lbg
import heatmap
import plots
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from mnist import load_mnist_data

# %%
data, labels = load_mnist_data([0, 1], sample_size = 200)
print(data.shape)
# Out:
# (784, 400)

# %%
k = kmeans.kmeans()
centers, labels = k.fit(data, true_labels = labels, center_count=2, show_cluster_data=True, plot_results=True, numits=100)
# Out:
# Epoch 1 cluster distortion: 590494.32659676
# Epoch 2 cluster distortion: 590369.71649158
# Epoch 3 cluster distortion: 590341.10567482
# Epoch 4 cluster distortion: 590329.64596392
# Epoch 5 cluster distortion: 590323.68452528
# Epoch 6 cluster distortion: 590320.09210700
# Epoch 7 cluster distortion: 590317.71341258
# Epoch 8 cluster distortion: 590316.03193851
# Epoch 9 cluster distortion: 590314.78494080
# Epoch 10 cluster distortion: 590313.82567926
# Epoch 11 cluster distortion: 590313.06618750
# Epoch 12 cluster distortion: 590312.45071849
# Epoch 13 cluster distortion: 590311.94232500
# Epoch 14 cluster distortion: 590311.51559979
# Epoch 15 cluster distortion: 590311.15252319
# Epoch 16 cluster distortion: 590310.83997526
# Epoch 17 cluster distortion: 590310.56818549
# Epoch 18 cluster distortion: 590310.32973364
# Epoch 19 cluster distortion: 590310.11888661
# Epoch 20 cluster distortion: 590309.93114703
# Epoch 21 cluster distortion: 590309.76293880
# Epoch 22 cluster distortion: 590309.61138375
# Epoch 23 cluster distortion: 590309.47413996
# Epoch 24 cluster distortion: 590309.34928292
# Epoch 25 cluster distortion: 590309.23521688
# Epoch 26 cluster distortion: 590309.13060774
# Epoch 27 cluster distortion: 590309.03433173
# Epoch 28 cluster distortion: 590308.94543569
# Epoch 29 cluster distortion: 590308.86310594
# Epoch 30 cluster distortion: 590308.78664377
# Epoch 31 cluster distortion: 590308.71544587
# Epoch 32 cluster distortion: 590308.64898867
# Epoch 33 cluster distortion: 590308.58681554
# Epoch 34 cluster distortion: 590308.52852655
# Epoch 35 cluster distortion: 590308.47376988
# Epoch 36 cluster distortion: 590308.42223485
# Epoch 37 cluster distortion: 590308.37364609
# Epoch 38 cluster distortion: 590308.32775864
# Epoch 39 cluster distortion: 590308.28435394
# Epoch 40 cluster distortion: 590308.24323630
# Epoch 41 cluster distortion: 590308.20423004
# Epoch 42 cluster distortion: 590308.16717699
# Epoch 43 cluster distortion: 590308.13193435
# Epoch 44 cluster distortion: 590308.09837288
# Epoch 45 cluster distortion: 590308.06637535
# Epoch 46 cluster distortion: 590308.03583515
# Epoch 47 cluster distortion: 590308.00665512
# Epoch 48 cluster distortion: 590307.97874656
# Epoch 49 cluster distortion: 590307.95202827
# Epoch 50 cluster distortion: 590307.92642583
# Epoch 51 cluster distortion: 590307.90187090
# Epoch 52 cluster distortion: 590307.87830058
# Epoch 53 cluster distortion: 590307.85565689
# Epoch 54 cluster distortion: 590307.83388635
# Epoch 55 cluster distortion: 590307.81293946
# Epoch 56 cluster distortion: 590307.79277044
# Epoch 57 cluster distortion: 590307.77333679
# Epoch 58 cluster distortion: 590307.75459907
# Epoch 59 cluster distortion: 590307.73652061
# Epoch 60 cluster distortion: 590307.71906726
# Epoch 61 cluster distortion: 590307.70220720
# Epoch 62 cluster distortion: 590307.68591070
# Epoch 63 cluster distortion: 590307.67015001
# Epoch 64 cluster distortion: 590307.65489917
# Epoch 65 cluster distortion: 590307.64013386
# Epoch 66 cluster distortion: 590307.62583127
# Epoch 67 cluster distortion: 590307.61197001
# Epoch 68 cluster distortion: 590307.59853000
# Epoch 69 cluster distortion: 590307.58549233
# Epoch 70 cluster distortion: 590307.57283921
# Epoch 71 cluster distortion: 590307.56055391
# Epoch 72 cluster distortion: 590307.54862062
# Epoch 73 cluster distortion: 590307.53702445
# Epoch 74 cluster distortion: 590307.52575132
# Epoch 75 cluster distortion: 590307.51478792
# Epoch 76 cluster distortion: 590307.50412168
# Epoch 77 cluster distortion: 590307.49374069
# Epoch 78 cluster distortion: 590307.48363366
# Epoch 79 cluster distortion: 590307.47378990
# Epoch 80 cluster distortion: 590307.46419926
# Epoch 81 cluster distortion: 590307.45485212
# Epoch 82 cluster distortion: 590307.44573931
# Epoch 83 cluster distortion: 590307.43685215
# Epoch 84 cluster distortion: 590307.42818236
# Epoch 85 cluster distortion: 590307.41972206
# Epoch 86 cluster distortion: 590307.41146377
# Epoch 87 cluster distortion: 590307.40340033
# Epoch 88 cluster distortion: 590307.39552494
# Epoch 89 cluster distortion: 590307.38783109
# Epoch 90 cluster distortion: 590307.38031259
# Epoch 91 cluster distortion: 590307.37296350
# Epoch 92 cluster distortion: 590307.36577818
# Epoch 93 cluster distortion: 590307.35875121
# Epoch 94 cluster distortion: 590307.35187742
# Epoch 95 cluster distortion: 590307.34515185
# Epoch 96 cluster distortion: 590307.33856976
# Epoch 97 cluster distortion: 590307.33212662
# Epoch 98 cluster distortion: 590307.32581807
# Epoch 99 cluster distortion: 590307.31963994
# Epoch 100 cluster distortion: 590307.31358824
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 590307.3136

# %%
l = lbg.lbg()
centers, labels = l.fit(data, center_count = 2, true_labels=labels, show_cluster_data=True, plot_results=True)
# Out:
# Iteration 1 cluster distortion: 695522.36185695
# Iteration 2 cluster distortion: 666265.74293175
# Iteration 3 cluster distortion: 594994.48203872
# Iteration 4 cluster distortion: 590760.66534880
# Iteration 5 cluster distortion: 590405.57896281
# Iteration 6 cluster distortion: 590353.50844280
# Iteration 7 cluster distortion: 590353.50844280
# LBG terminated after 7 iterations
#
# Final cluster distortion: 590353.5084
