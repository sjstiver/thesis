# %%
import numpy as np
import scipy as sp
import distances
import gr_kmeans
import gr_lbg
import matplotlib.pyplot as plt
import plots
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from subspaces import make_subspaces

# %%
data, labels = load_ip_data([10, 11, 12], sample_size = 10000)
# Out:
# Class 10 name: Soybean-notill
# Sample number for class 10 reduced to 972
# Class 11 name: Soybean-mintill
# Sample number for class 11 reduced to 2455
# Class 12 name: Soybean-clean
# Sample number for class 12 reduced to 593

# %% [markdown]
# ### Gr(5, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=5)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.title('Embedded Data')
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1449.8774
# Cluster purity calculations:
# Average cluster purity: 0.6380 +/- 0.0140
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6488
# Classification BSR based on highest probability labels:
# BSR: 0.6380

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 12 iterations
#
# Final cluster distortion: 1428.9839
# Cluster purity calculations:
# Average cluster purity: 0.6592 +/- 0.0264
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6115
# Classification BSR based on highest probability labels:
# BSR: 0.6592

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1419.5810
# Cluster purity calculations:
# Average cluster purity: 0.7742 +/- 0.0176
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7210
# Classification BSR based on highest probability labels:
# BSR: 0.7742

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 13 iterations
#
# Final cluster distortion: 1353.8881
# Cluster purity calculations:
# Average cluster purity: 0.7124 +/- 0.0197
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6874
# Classification BSR based on highest probability labels:
# BSR: 0.7124

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1370.4411
# Cluster purity calculations:
# Average cluster purity: 0.7472 +/- 0.0409
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6775
# Classification BSR based on highest probability labels:
# BSR: 0.7472

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100)
# Out:
# LBG terminated after 14 iterations
#
# Final cluster distortion: 1318.5589
# Cluster purity calculations:
# Average cluster purity: 0.7443 +/- 0.0135
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7385
# Classification BSR based on highest probability labels:
# BSR: 0.7443

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ### Gr(10, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=10)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1517.3351
# Cluster purity calculations:
# Average cluster purity: 0.7044 +/- 0.0458
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6135
# Classification BSR based on highest probability labels:
# BSR: 0.7044

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 8 iterations
#
# Final cluster distortion: 1410.1294
# Cluster purity calculations:
# Average cluster purity: 0.7390 +/- 0.0160
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7706
# Classification BSR based on highest probability labels:
# BSR: 0.7390

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1473.0710
# Cluster purity calculations:
# Average cluster purity: 0.8274 +/- 0.0362
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7107
# Classification BSR based on highest probability labels:
# BSR: 0.8274

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 10 iterations
#
# Final cluster distortion: 1356.1370
# Cluster purity calculations:
# Average cluster purity: 0.8347 +/- 0.0168
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8379
# Classification BSR based on highest probability labels:
# BSR: 0.8347

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1459.4514
# Cluster purity calculations:
# Average cluster purity: 0.9517 +/- 0.0098
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7257
# Classification BSR based on highest probability labels:
# BSR: 0.9517

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100)
# Out:
# LBG terminated after 12 iterations
#
# Final cluster distortion: 1326.5439
# Cluster purity calculations:
# Average cluster purity: 0.8728 +/- 0.0082
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8504
# Classification BSR based on highest probability labels:
# BSR: 0.8728

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ### Gr(15,200)

# %%
sub, lbls = make_subspaces(data, labels, dim=15)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1444.0445
# Cluster purity calculations:
# Average cluster purity: 0.8712 +/- 0.0332
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6165
# Classification BSR based on highest probability labels:
# BSR: 0.8712

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 10 iterations
#
# Final cluster distortion: 1353.9093
# Cluster purity calculations:
# Average cluster purity: 0.7000 +/- 0.0068
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7256
# Classification BSR based on highest probability labels:
# BSR: 0.7000

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1346.2289
# Cluster purity calculations:
# Average cluster purity: 0.9438 +/- 0.0057
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8947
# Classification BSR based on highest probability labels:
# BSR: 0.9438

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 13 iterations
#
# Final cluster distortion: 1293.8406
# Cluster purity calculations:
# Average cluster purity: 0.8961 +/- 0.0099
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8496
# Classification BSR based on highest probability labels:
# BSR: 0.8961

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)
