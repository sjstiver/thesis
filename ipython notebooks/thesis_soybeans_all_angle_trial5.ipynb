# %%
# changed kmeans distortion to calculate delta every iteration instead of every epoch

import numpy as np
import scipy as sp
import distances
import gr_kmeans
import gr_lbg
import matplotlib.pyplot as plt
import plots
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from subspaces import make_subspaces

# %%
data, labels = load_ip_data([10, 11, 12], sample_size = 10000)
# Out:
# Class 10 name: Soybean-notill
# Sample number for class 10 reduced to 972
# Class 11 name: Soybean-mintill
# Sample number for class 11 reduced to 2455
# Class 12 name: Soybean-clean
# Sample number for class 12 reduced to 593

# %% [markdown]
# ### Gr(5, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=5)

# %%
dist_metric = 'angle'
D = distances.prin_angle_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.title('Embedded Data')
plt.show()

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 4 iterations
#
# Final cluster distortion: 5.0814
# Cluster purity calculations:
# Average cluster purity: 0.8435 +/- 0.0137
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8680
# Classification BSR based on highest probability labels:
# BSR: 0.8435

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100, 
                                  dist_metric=dist_metric)
# Out:
# LBG terminated after 100 iterations
#
# Final cluster distortion: 4.7656
# Cluster purity calculations:
# Average cluster purity: 0.8205 +/- 0.0230
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8344
# Classification BSR based on highest probability labels:
# BSR: 0.8205

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 13 iterations
#
# Final cluster distortion: 4.8457
# Cluster purity calculations:
# Average cluster purity: 0.8790 +/- 0.0205
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8792
# Classification BSR based on highest probability labels:
# BSR: 0.8790

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 100 iterations
#
# Final cluster distortion: 4.5960
# Cluster purity calculations:
# Average cluster purity: 0.8760 +/- 0.0094
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8804
# Classification BSR based on highest probability labels:
# BSR: 0.8760

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ### Gr(10, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=10)

# %%
D = distances.prin_angle_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 11 iterations
#
# Final cluster distortion: 1.2539
# Cluster purity calculations:
# Average cluster purity: 0.8855 +/- 0.0066
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8279
# Classification BSR based on highest probability labels:
# BSR: 0.8855

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 10 iterations
#
# Final cluster distortion: 1.1040
# Cluster purity calculations:
# Average cluster purity: 0.9637 +/- 0.0008
# Classification accuracy based on highest probability labels:
# Accuracy: 0.9576
# Classification BSR based on highest probability labels:
# BSR: 0.9637

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 55 iterations
#
# Final cluster distortion: 1.1530
# Cluster purity calculations:
# Average cluster purity: 0.9809 +/- 0.0004
# Classification accuracy based on highest probability labels:
# Accuracy: 0.9701
# Classification BSR based on highest probability labels:
# BSR: 0.9809

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 100 iterations
#
# Final cluster distortion: 1.0825
# Cluster purity calculations:
# Average cluster purity: 0.9730 +/- 0.0005
# Classification accuracy based on highest probability labels:
# Accuracy: 0.9651
# Classification BSR based on highest probability labels:
# BSR: 0.9730

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 7 iterations
#
# Final cluster distortion: 1.1438
# Cluster purity calculations:
# Average cluster purity: 0.9833 +/- 0.0010
# Classification accuracy based on highest probability labels:
# Accuracy: 0.9451
# Classification BSR based on highest probability labels:
# BSR: 0.9833

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 100 iterations
#
# Final cluster distortion: 1.0718
# Cluster purity calculations:
# Average cluster purity: 0.9825 +/- 0.0013
# Classification accuracy based on highest probability labels:
# Accuracy: 0.9576
# Classification BSR based on highest probability labels:
# BSR: 0.9825

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ### Gr(15,200)

# %%
sub, lbls = make_subspaces(data, labels, dim=15)

# %%
D = distances.prin_angle_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 32 iterations
#
# Final cluster distortion: 0.4839
# Cluster purity calculations:
# Average cluster purity: 0.9868 +/- 0.0001
# Classification accuracy based on highest probability labels:
# Accuracy: 0.9812
# Classification BSR based on highest probability labels:
# BSR: 0.9868

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 6 iterations
#
# Final cluster distortion: 0.4572
# Cluster purity calculations:
# Average cluster purity: 0.9908 +/- 0.0000
# Classification accuracy based on highest probability labels:
# Accuracy: 0.9887
# Classification BSR based on highest probability labels:
# BSR: 0.9908

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 89 iterations
#
# Final cluster distortion: 0.4754
# Cluster purity calculations:
# Average cluster purity: 0.9971 +/- 0.0000
# Classification accuracy based on highest probability labels:
# Accuracy: 0.9962
# Classification BSR based on highest probability labels:
# BSR: 0.9971

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 35 iterations
#
# Final cluster distortion: 0.4499
# Cluster purity calculations:
# Average cluster purity: 0.9974 +/- 0.0000
# Classification accuracy based on highest probability labels:
# Accuracy: 0.9962
# Classification BSR based on highest probability labels:
# BSR: 0.9974

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)
