# %%
import numpy as np

# %% [markdown]
# #### Soybeans all method comparison

# %%
euclid_cluster_pur_kmeans = [1255/(1255+551+138), 926/(926+230+250), 274/(191+274+205), 1036/(255+1036+257), 223/(130+223+183),
                            1196/(587+1196+153), 1075/(265+1075+261), 199/(105+199+171), 1181/(602+1181+161), 
                             1178/(603+1178+168), 189/(102+189+163), 1088/(1088+267+262), 1232/(545+1232+138), 
                            274/(191+274+205), 949/(236+949+250), 274/(191+274+205), 947/(947+236+250), 1234/(1234+545+138),
                            274/(191+274+205), 927/(927+230+250), 1254/(1254+551+138), 1244/(1244+553+139), 271/(185+271+204),
                            940/(234+940+250), 263/(108+263+202), 1247/(1247+557+141), 945/(945+235+250), 1196/(1196+587+153),
                            1036/(1036+255+257), 223/(223+130+183)]

euclid_cluster_pur_lbg = [1018/(1018+251+256), 1233/(612+166+1233), 204/(109+204+171), 1233/(612+1233+166), 1018/(1018+251+256),
                         204/(109+204+171), 1018/(1018+251+256), 1233/(612+166+1233), 204/(109+204+171), 1018/(1018+251+256), 
                          1233/(612+166+1233), 204/(109+204+171), 1233/(612+166+1233), 204/(109+204+171), 1018/(1018+251+256),
                         1232/(611+165+1232), 1024/(1024+253+257), 199/(108+199+171), 1233/(612+1233+166), 204/(109+204+171),
                         1018/(1018+251+256), 199/(108+199+171), 1024/(1024+253+257), 1232/(611+165+1232), 1018/(1018+251+256),
                         1233/(612+166+1233), 204/(109+204+171), 1018/(1018+251+256), 1233/(612+166+1233), 204/(109+204+171)]

embed_cluster_pur_kmeans = [164/(164+12+79), 1/1, 478/(30+478+39), 1/1, 466/(17+466+4), 177/(177+24+114), 474/(42+474), 
                            154/(154+116+16), 1, 175/(175+182+21), 97/103, 406/422, 1, 1, 489/(194+489+118), 1, 1, 
                           491/(194+489+118), 110/(110+5+18), 1, 485/(485+176+8), 1, 475/(475+58), 165/(165+16+88), 1, 
                           154/(154+116+17), 473/(473+42), 154/(154+116+17), 1, 474/(474+42)]

embed_cluster_pur_lbg = [132/(132+10+104), 208/(45+208+9), 273/(17+273+5), 462/(23+462+1), 167/(167+25+11), 106/(4+4+106), 
                        463/(463+25), 105/(105+7), 167/(167+24+12), 106/(4+4+106), 167/(167+24+11), 463/(463+24), 109/116,
                        166/(166+24+8), 463/(463+26), 99/(99+6+19), 156/(100+156+19), 385/(385+19), 381/(381+19), 100/122,
                        158/(158+106+17), 167/(167+25+12), 462/(462+25), 104/112, 173/(173+78+21), 409/(409+17), 97/105, 
                        173/(173+54+26), 308/(308+26), 118/(118+98)]

gr_cluster_pur_kmeans = [73/(2+1+73), 465/(40+465+5), 152/(152+25+40), 177/(177+55+46), 435/(16+435+2), 70/72, 435/(435+18),
                        177/(177+55+46), 70/72, 75/79, 175/(175+64+41), 424/444, 177/(177+55+46), 435/(16+435+2), 70/72, 
                        153/(153+27+32), 462/(462+42), 84/87, 462/(462+42), 84/87, 153/(153+27+32), 84/87, 153/(153+27+32),
                        462/(462+42), ]

gr_cluster_pur_lbg = [127/(127+69+12), 104/(50+9+104), 413/(17+413+2), 127/(127+78+12), 406/426, 103/160, 172/(172+72+29),
                     419/439, 88/91, 88/91, 420/440, 173/(173+70+29), 88/91, 172/(172+69+29), 422/442, 127/(127+89+13), 
                     103/(103+58), 394/(394+19), 435/(435+18), 117/(117+55+46), 70/72, 106/(106+9+53), 407/(407+18), 
                      125/(125+85), 120/(120+88+10), 105/(105+57+9), 394/(394+20), 422/442, 88/91, 172/(172+69+29)]

# %%
print('%.4f +\- %.4f'%(np.mean(euclid_cluster_pur_kmeans), np.std(euclid_cluster_pur_kmeans)))
# Out:
# 0.5708 +\- 0.1102

# %%
print('%.4f +\- %.4f'%(np.mean(euclid_cluster_pur_lbg), np.std(euclid_cluster_pur_lbg)))
# Out:
# 0.5671 +\- 0.1060

# %%
print('%.4f +\- %.4f'%(np.mean(embed_cluster_pur_kmeans), np.std(embed_cluster_pur_kmeans)))
# Out:
# 0.8350 +\- 0.1866

# %%
print('%.4f +\- %.4f'%(np.mean(embed_cluster_pur_lbg), np.std(embed_cluster_pur_lbg)))
# Out:
# 0.8374 +\- 0.1372

# %%
print('%.4f +\- %.4f'%(np.mean(gr_cluster_pur_kmeans), np.std(gr_cluster_pur_kmeans)))
# Out:
# 0.8592 +\- 0.1336

# %%
print('%.4f +\- %.4f'%(np.mean(gr_cluster_pur_lbg), np.std(gr_cluster_pur_lbg)))
# Out:
# 0.7844 +\- 0.1769

# %% [markdown]
# #### MNIST 10 cluster averages

# %%
euclidean_kmeans = [201/(3+5+21+16+83+187+11+69+201+121), 189/(3+2+16+7+189+17+41+46+12+179), 339/(1+2+2+5+4+339+3+70),
                   389/(13+305+2+11+6+389+9+3), 202/(1+202+5+8+6+109), 218/(55+2+23+218+127+51+1+8),
                    215/(9+1+37+215+136+7+179+9), 489/(489+89+32+10+9+37+37+34+5), 211/(211+7+5), 206/(206+7+9+6+3+2)]

euclidean_lbg = [401/(27+18+1+7+11+401+9+3), 359/(359+3+3+5+1+1), 224/(5+2+8+123+1+93+2+1+224+5), 327/(1+327+11+2+1+2+4+3),
                193/(12+10+7+193+20+46+43+15+145), 187/(1+1+163+5+187+18+138), 492/(492+92+35+19+69+28+45+45+11), 
                220/(1+3+108+14+220+3+192), 157/(83+3+13+89+7+157+15+151+1), 231/(14+1+27+231+127+1+31+4)]

gr_kmeans = [99/101, 1, 1, 1, 98/99, 1, 1, 1, 100/166, 100/134]

gr_lbg = [1, 1, 100/110, 1, 1, 1, 100/190, 1, 1, 1]

# %%
print('%.4f +\- %.4f'%(np.mean(euclidean_kmeans), np.std(euclidean_kmeans)))
# Out:
# 0.5884 +\- 0.2193

# %%
print('%.4f +\- %.4f'%(np.mean(euclidean_lbg), np.std(euclidean_lbg)))
# Out:
# 0.5805 +\- 0.2324

# %%
print('%.4f +\- %.4f'%(np.mean(gr_kmeans), np.std(gr_kmeans)))
# Out:
# 0.9319 +\- 0.1329

# %%
print('%.4f +\- %.4f'%(np.mean(gr_lbg), np.std(gr_lbg)))
# Out:
# 0.9435 +\- 0.1417
