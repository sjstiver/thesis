# %%
import numpy as np
import scipy as sp
import distances
import gr_kmeans
import gr_lbg
import matplotlib.pyplot as plt
import plots
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from subspaces import make_subspaces

# %%
data, labels = load_ip_data([10, 11, 12], sample_size = 10000)
# Out:
# Class 10 name: Soybean-notill
# Sample number for class 10 reduced to 972
# Class 11 name: Soybean-mintill
# Sample number for class 11 reduced to 2455
# Class 12 name: Soybean-clean
# Sample number for class 12 reduced to 593

# %% [markdown]
# ### Gr(5, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=5)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.title('Embedded Data')
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1439.5056
# Cluster purity calculations:
# Average cluster purity: 0.6587 +/- 0.0173
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6351
# Classification BSR based on highest probability labels:
# BSR: 0.6587

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 15 iterations
#
# Final cluster distortion: 1425.5999
# Cluster purity calculations:
# Average cluster purity: 0.6479 +/- 0.0119
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6314
# Classification BSR based on highest probability labels:
# BSR: 0.6479

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1405.4615
# Cluster purity calculations:
# Average cluster purity: 0.7510 +/- 0.0291
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6800
# Classification BSR based on highest probability labels:
# BSR: 0.7510

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 16 iterations
#
# Final cluster distortion: 1353.5813
# Cluster purity calculations:
# Average cluster purity: 0.7082 +/- 0.0189
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6899
# Classification BSR based on highest probability labels:
# BSR: 0.7082

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1399.9563
# Cluster purity calculations:
# Average cluster purity: 0.7721 +/- 0.0373
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6725
# Classification BSR based on highest probability labels:
# BSR: 0.7721

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100)
# Out:
# LBG terminated after 38 iterations
#
# Final cluster distortion: 1324.3607
# Cluster purity calculations:
# Average cluster purity: 0.7135 +/- 0.0235
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6849
# Classification BSR based on highest probability labels:
# BSR: 0.7135

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ### Gr(10, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=10)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1487.9007
# Cluster purity calculations:
# Average cluster purity: 0.8790 +/- 0.0171
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7282
# Classification BSR based on highest probability labels:
# BSR: 0.8790

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 7 iterations
#
# Final cluster distortion: 1429.8094
# Cluster purity calculations:
# Average cluster purity: 0.6843 +/- 0.0402
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6858
# Classification BSR based on highest probability labels:
# BSR: 0.6843

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1424.7358
# Cluster purity calculations:
# Average cluster purity: 0.8997 +/- 0.0302
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7581
# Classification BSR based on highest probability labels:
# BSR: 0.8997

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 23 iterations
#
# Final cluster distortion: 1361.2461
# Cluster purity calculations:
# Average cluster purity: 0.8160 +/- 0.0230
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8155
# Classification BSR based on highest probability labels:
# BSR: 0.8160

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1408.5184
# Cluster purity calculations:
# Average cluster purity: 0.8820 +/- 0.0391
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7232
# Classification BSR based on highest probability labels:
# BSR: 0.8820

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100)
# Out:
# LBG terminated after 8 iterations
#
# Final cluster distortion: 1332.1494
# Cluster purity calculations:
# Average cluster purity: 0.8456 +/- 0.0138
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8329
# Classification BSR based on highest probability labels:
# BSR: 0.8456

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ### Gr(15,200)

# %%
sub, lbls = make_subspaces(data, labels, dim=15)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1443.1729
# Cluster purity calculations:
# Average cluster purity: 0.8699 +/- 0.0338
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6128
# Classification BSR based on highest probability labels:
# BSR: 0.8699

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 9 iterations
#
# Final cluster distortion: 1342.3902
# Cluster purity calculations:
# Average cluster purity: 0.7563 +/- 0.0030
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7594
# Classification BSR based on highest probability labels:
# BSR: 0.7563

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1383.2555
# Cluster purity calculations:
# Average cluster purity: 0.9295 +/- 0.0100
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7857
# Classification BSR based on highest probability labels:
# BSR: 0.9295

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 8 iterations
#
# Final cluster distortion: 1293.6236
# Cluster purity calculations:
# Average cluster purity: 0.8283 +/- 0.0161
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8571
# Classification BSR based on highest probability labels:
# BSR: 0.8283

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)
