# %%
# changed kmeans distortion to calculate delta every iteration instead of every epoch

import numpy as np
import scipy as sp
import distances
import gr_kmeans
import gr_lbg
import matplotlib.pyplot as plt
import plots
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from subspaces import make_subspaces

# %%
data, labels = load_ip_data([10, 11, 12], sample_size = 10000)
# Out:
# Class 10 name: Soybean-notill
# Sample number for class 10 reduced to 972
# Class 11 name: Soybean-mintill
# Sample number for class 11 reduced to 2455
# Class 12 name: Soybean-clean
# Sample number for class 12 reduced to 593

# %% [markdown]
# ### Gr(5, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=5)

# %%
dist_metric = 'geodesic'
D = distances.geodesic_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.title('Embedded Data')
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2291.3367
# Cluster purity calculations:
# Average cluster purity: 0.6067 +/- 0.0030
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6115
# Classification BSR based on highest probability labels:
# BSR: 0.6067

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100, 
                                  dist_metric=dist_metric)
# Out:
# LBG terminated after 11 iterations
#
# Final cluster distortion: 2267.7017
# Cluster purity calculations:
# Average cluster purity: 0.6384 +/- 0.0082
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6625
# Classification BSR based on highest probability labels:
# BSR: 0.6384

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2100.1058
# Cluster purity calculations:
# Average cluster purity: 0.6566 +/- 0.0172
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6712
# Classification BSR based on highest probability labels:
# BSR: 0.6566

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100, 
                                  dist_metric=dist_metric)
# Out:
# LBG terminated after 11 iterations
#
# Final cluster distortion: 2111.0995
# Cluster purity calculations:
# Average cluster purity: 0.6728 +/- 0.0135
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6800
# Classification BSR based on highest probability labels:
# BSR: 0.6728

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2019.9718
# Cluster purity calculations:
# Average cluster purity: 0.6529 +/- 0.0340
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6912
# Classification BSR based on highest probability labels:
# BSR: 0.6529

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 17 iterations
#
# Final cluster distortion: 2010.7087
# Cluster purity calculations:
# Average cluster purity: 0.6817 +/- 0.0112
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6725
# Classification BSR based on highest probability labels:
# BSR: 0.6817

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ### Gr(10, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=10)

# %%
D = distances.geodesic_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2376.4526
# Cluster purity calculations:
# Average cluster purity: 0.7662 +/- 0.0574
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6608
# Classification BSR based on highest probability labels:
# BSR: 0.7662

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 16 iterations
#
# Final cluster distortion: 2331.8201
# Cluster purity calculations:
# Average cluster purity: 0.6857 +/- 0.0245
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7182
# Classification BSR based on highest probability labels:
# BSR: 0.6857

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2271.4990
# Cluster purity calculations:
# Average cluster purity: 0.7968 +/- 0.0495
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6833
# Classification BSR based on highest probability labels:
# BSR: 0.7968

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 25 iterations
#
# Final cluster distortion: 2205.5702
# Cluster purity calculations:
# Average cluster purity: 0.7362 +/- 0.0150
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7706
# Classification BSR based on highest probability labels:
# BSR: 0.7362

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2199.3060
# Cluster purity calculations:
# Average cluster purity: 0.8221 +/- 0.0428
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7606
# Classification BSR based on highest probability labels:
# BSR: 0.8221

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 15 iterations
#
# Final cluster distortion: 2118.2331
# Cluster purity calculations:
# Average cluster purity: 0.8353 +/- 0.0199
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8030
# Classification BSR based on highest probability labels:
# BSR: 0.8353

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ### Gr(15,200)

# %%
sub, lbls = make_subspaces(data, labels, dim=15)

# %%
D = distances.geodesic_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2275.9268
# Cluster purity calculations:
# Average cluster purity: 0.8133 +/- 0.0327
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7556
# Classification BSR based on highest probability labels:
# BSR: 0.8133

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 7 iterations
#
# Final cluster distortion: 2221.0040
# Cluster purity calculations:
# Average cluster purity: 0.7382 +/- 0.0405
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7368
# Classification BSR based on highest probability labels:
# BSR: 0.7382

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2167.5478
# Cluster purity calculations:
# Average cluster purity: 0.9383 +/- 0.0070
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8947
# Classification BSR based on highest probability labels:
# BSR: 0.9383

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 8 iterations
#
# Final cluster distortion: 2090.0323
# Cluster purity calculations:
# Average cluster purity: 0.8568 +/- 0.0193
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8534
# Classification BSR based on highest probability labels:
# BSR: 0.8568

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)
