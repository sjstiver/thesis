# %%
import numpy as np
import scipy as sp
import distances
import kmeans
import lbg
import heatmap
import plots
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from mnist import load_mnist_data

# %%
data, labels = load_mnist_data([0, 1], sample_size = 200)
print(data.shape)
# Out:
# (784, 400)

# %%
k = kmeans.kmeans()
centers, labels = k.fit(data, true_labels = labels, center_count=2, show_cluster_data=True, plot_results=True, numits=100)
# Out:
# Epoch 1 cluster distortion: 584043.37402164
# Epoch 2 cluster distortion: 584051.06846489
# Kmeans terminated after 2 iterations
#
# Final cluster distortion: 584051.0685

# %%
l = lbg.lbg()
centers, labels = l.fit(data, center_count = 2, true_labels=labels, show_cluster_data=True, plot_results=True)
# Out:
# Iteration 1 cluster distortion: 673787.34773462
# Iteration 2 cluster distortion: 610646.14116258
# Iteration 3 cluster distortion: 585654.67720534
# Iteration 4 cluster distortion: 584071.34213633
# Iteration 5 cluster distortion: 584088.60903110
# Iteration 6 cluster distortion: 584088.60903110
# LBG terminated after 6 iterations
#
# Final cluster distortion: 584088.6090
