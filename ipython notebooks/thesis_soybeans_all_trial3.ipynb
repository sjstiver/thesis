# %%
import numpy as np
import scipy as sp
import distances
import gr_kmeans
import gr_lbg
import matplotlib.pyplot as plt
import plots
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from subspaces import make_subspaces

# %%
data, labels = load_ip_data([10, 11, 12], sample_size = 10000)
# Out:
# Class 10 name: Soybean-notill
# Sample number for class 10 reduced to 972
# Class 11 name: Soybean-mintill
# Sample number for class 11 reduced to 2455
# Class 12 name: Soybean-clean
# Sample number for class 12 reduced to 593

# %% [markdown]
# ### Gr(5, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=5)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.title('Embedded Data')
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1445.9697
# Cluster purity calculations:
# Average cluster purity: 0.6690 +/- 0.0064
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6775
# Classification BSR based on highest probability labels:
# BSR: 0.6690

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 19 iterations
#
# Final cluster distortion: 1430.8644
# Cluster purity calculations:
# Average cluster purity: 0.6809 +/- 0.0173
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6737
# Classification BSR based on highest probability labels:
# BSR: 0.6809

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1419.2121
# Cluster purity calculations:
# Average cluster purity: 0.6812 +/- 0.0519
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6588
# Classification BSR based on highest probability labels:
# BSR: 0.6812

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 23 iterations
#
# Final cluster distortion: 1361.2755
# Cluster purity calculations:
# Average cluster purity: 0.6916 +/- 0.0190
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7011
# Classification BSR based on highest probability labels:
# BSR: 0.6916

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1382.4298
# Cluster purity calculations:
# Average cluster purity: 0.7244 +/- 0.0283
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6824
# Classification BSR based on highest probability labels:
# BSR: 0.7244

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100)
# Out:
# LBG terminated after 17 iterations
#
# Final cluster distortion: 1336.5854
# Cluster purity calculations:
# Average cluster purity: 0.7769 +/- 0.0169
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7198
# Classification BSR based on highest probability labels:
# BSR: 0.7769

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ### Gr(10, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=10)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1519.9054
# Cluster purity calculations:
# Average cluster purity: 0.8697 +/- 0.0340
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6110
# Classification BSR based on highest probability labels:
# BSR: 0.8697

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 12 iterations
#
# Final cluster distortion: 1417.8370
# Cluster purity calculations:
# Average cluster purity: 0.6681 +/- 0.0304
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7007
# Classification BSR based on highest probability labels:
# BSR: 0.6681

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1425.1721
# Cluster purity calculations:
# Average cluster purity: 0.9072 +/- 0.0234
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7930
# Classification BSR based on highest probability labels:
# BSR: 0.9072

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 11 iterations
#
# Final cluster distortion: 1353.7160
# Cluster purity calculations:
# Average cluster purity: 0.8327 +/- 0.0238
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8105
# Classification BSR based on highest probability labels:
# BSR: 0.8327

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1464.1626
# Cluster purity calculations:
# Average cluster purity: 0.9581 +/- 0.0094
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7232
# Classification BSR based on highest probability labels:
# BSR: 0.9581

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100)
# Out:
# LBG terminated after 13 iterations
#
# Final cluster distortion: 1333.2551
# Cluster purity calculations:
# Average cluster purity: 0.8752 +/- 0.0063
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8628
# Classification BSR based on highest probability labels:
# BSR: 0.8752

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ### Gr(15,200)

# %%
sub, lbls = make_subspaces(data, labels, dim=15)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1371.7558
# Cluster purity calculations:
# Average cluster purity: 0.9013 +/- 0.0075
# Classification accuracy based on highest probability labels:
# Accuracy: 0.9060
# Classification BSR based on highest probability labels:
# BSR: 0.9013

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 4 iterations
#
# Final cluster distortion: 1342.2690
# Cluster purity calculations:
# Average cluster purity: 0.7878 +/- 0.0182
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8383
# Classification BSR based on highest probability labels:
# BSR: 0.7878

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1428.4320
# Cluster purity calculations:
# Average cluster purity: 0.9361 +/- 0.0204
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6241
# Classification BSR based on highest probability labels:
# BSR: 0.9361

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 10 iterations
#
# Final cluster distortion: 1292.6919
# Cluster purity calculations:
# Average cluster purity: 0.8616 +/- 0.0119
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8759
# Classification BSR based on highest probability labels:
# BSR: 0.8616

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)
