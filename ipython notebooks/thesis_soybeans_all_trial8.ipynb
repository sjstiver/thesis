# %%
import numpy as np
import scipy as sp
import distances
import gr_kmeans
import gr_lbg
import matplotlib.pyplot as plt
import plots
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from subspaces import make_subspaces

# %%
data, labels = load_ip_data([10, 11, 12], sample_size = 10000)
# Out:
# Class 10 name: Soybean-notill
# Sample number for class 10 reduced to 972
# Class 11 name: Soybean-mintill
# Sample number for class 11 reduced to 2455
# Class 12 name: Soybean-clean
# Sample number for class 12 reduced to 593

# %% [markdown]
# ### Gr(5, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=5)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.title('Embedded Data')
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1461.0638
# Cluster purity calculations:
# Average cluster purity: 0.6644 +/- 0.0046
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6775
# Classification BSR based on highest probability labels:
# BSR: 0.6644

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 18 iterations
#
# Final cluster distortion: 1429.3613
# Cluster purity calculations:
# Average cluster purity: 0.6597 +/- 0.0051
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6800
# Classification BSR based on highest probability labels:
# BSR: 0.6597

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1395.9188
# Cluster purity calculations:
# Average cluster purity: 0.7113 +/- 0.0364
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6737
# Classification BSR based on highest probability labels:
# BSR: 0.7113

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 29 iterations
#
# Final cluster distortion: 1354.2209
# Cluster purity calculations:
# Average cluster purity: 0.7003 +/- 0.0178
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6787
# Classification BSR based on highest probability labels:
# BSR: 0.7003

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1364.3485
# Cluster purity calculations:
# Average cluster purity: 0.6726 +/- 0.0405
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6887
# Classification BSR based on highest probability labels:
# BSR: 0.6726

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100)
# Out:
# LBG terminated after 17 iterations
#
# Final cluster distortion: 1326.6647
# Cluster purity calculations:
# Average cluster purity: 0.7657 +/- 0.0159
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7335
# Classification BSR based on highest probability labels:
# BSR: 0.7657

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ### Gr(10, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=10)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1517.3351
# Cluster purity calculations:
# Average cluster purity: 0.7044 +/- 0.0458
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6135
# Classification BSR based on highest probability labels:
# BSR: 0.7044

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 22 iterations
#
# Final cluster distortion: 1417.1269
# Cluster purity calculations:
# Average cluster purity: 0.7282 +/- 0.0276
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7057
# Classification BSR based on highest probability labels:
# BSR: 0.7282

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1422.6557
# Cluster purity calculations:
# Average cluster purity: 0.9059 +/- 0.0279
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7731
# Classification BSR based on highest probability labels:
# BSR: 0.9059

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 21 iterations
#
# Final cluster distortion: 1357.3203
# Cluster purity calculations:
# Average cluster purity: 0.8779 +/- 0.0032
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8653
# Classification BSR based on highest probability labels:
# BSR: 0.8779

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1384.3019
# Cluster purity calculations:
# Average cluster purity: 0.7739 +/- 0.0422
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7706
# Classification BSR based on highest probability labels:
# BSR: 0.7739

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100)
# Out:
# LBG terminated after 15 iterations
#
# Final cluster distortion: 1334.9222
# Cluster purity calculations:
# Average cluster purity: 0.8698 +/- 0.0202
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8404
# Classification BSR based on highest probability labels:
# BSR: 0.8698

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ### Gr(15,200)

# %%
sub, lbls = make_subspaces(data, labels, dim=15)

# %%
D = distances.chordal_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1409.5575
# Cluster purity calculations:
# Average cluster purity: 0.8722 +/- 0.0141
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7444
# Classification BSR based on highest probability labels:
# BSR: 0.8722

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100)
# Out:
# LBG terminated after 8 iterations
#
# Final cluster distortion: 1342.5366
# Cluster purity calculations:
# Average cluster purity: 0.7625 +/- 0.0445
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7331
# Classification BSR based on highest probability labels:
# BSR: 0.7625

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 1352.9411
# Cluster purity calculations:
# Average cluster purity: 0.9571 +/- 0.0029
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8835
# Classification BSR based on highest probability labels:
# BSR: 0.9571

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100)
# Out:
# LBG terminated after 17 iterations
#
# Final cluster distortion: 1298.8472
# Cluster purity calculations:
# Average cluster purity: 0.8941 +/- 0.0062
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8835
# Classification BSR based on highest probability labels:
# BSR: 0.8941

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers)
