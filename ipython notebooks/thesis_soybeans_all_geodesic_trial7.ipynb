# %%
# changed kmeans distortion to calculate delta every iteration instead of every epoch

import numpy as np
import scipy as sp
import distances
import gr_kmeans
import gr_lbg
import matplotlib.pyplot as plt
import plots
from mpl_toolkits import mplot3d
from load_ip_data import load_ip_data
from subspaces import make_subspaces

# %%
data, labels = load_ip_data([10, 11, 12], sample_size = 10000)
# Out:
# Class 10 name: Soybean-notill
# Sample number for class 10 reduced to 972
# Class 11 name: Soybean-mintill
# Sample number for class 11 reduced to 2455
# Class 12 name: Soybean-clean
# Sample number for class 12 reduced to 593

# %% [markdown]
# ### Gr(5, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=5)

# %%
dist_metric = 'geodesic'
D = distances.geodesic_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.title('Embedded Data')
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2278.0243
# Cluster purity calculations:
# Average cluster purity: 0.6359 +/- 0.0205
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6139
# Classification BSR based on highest probability labels:
# BSR: 0.6359

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100, 
                                  dist_metric=dist_metric)
# Out:
# LBG terminated after 18 iterations
#
# Final cluster distortion: 2258.0153
# Cluster purity calculations:
# Average cluster purity: 0.6209 +/- 0.0112
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6115
# Classification BSR based on highest probability labels:
# BSR: 0.6209

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2153.2381
# Cluster purity calculations:
# Average cluster purity: 0.6722 +/- 0.0193
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6924
# Classification BSR based on highest probability labels:
# BSR: 0.6722

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100, 
                                  dist_metric=dist_metric)
# Out:
# LBG terminated after 25 iterations
#
# Final cluster distortion: 2088.2667
# Cluster purity calculations:
# Average cluster purity: 0.6639 +/- 0.0179
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6650
# Classification BSR based on highest probability labels:
# BSR: 0.6639

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2017.7067
# Cluster purity calculations:
# Average cluster purity: 0.6291 +/- 0.0163
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6812
# Classification BSR based on highest probability labels:
# BSR: 0.6291

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 16 iterations
#
# Final cluster distortion: 2000.5899
# Cluster purity calculations:
# Average cluster purity: 0.6999 +/- 0.0117
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6949
# Classification BSR based on highest probability labels:
# BSR: 0.6999

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ### Gr(10, 200)

# %%
sub, lbls = make_subspaces(data, labels, dim=10)

# %%
D = distances.geodesic_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2493.1066
# Cluster purity calculations:
# Average cluster purity: 0.7035 +/- 0.0460
# Classification accuracy based on highest probability labels:
# Accuracy: 0.6110
# Classification BSR based on highest probability labels:
# BSR: 0.7035

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 15 iterations
#
# Final cluster distortion: 2330.5557
# Cluster purity calculations:
# Average cluster purity: 0.7122 +/- 0.0185
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7057
# Classification BSR based on highest probability labels:
# BSR: 0.7122

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2268.2856
# Cluster purity calculations:
# Average cluster purity: 0.8496 +/- 0.0238
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7556
# Classification BSR based on highest probability labels:
# BSR: 0.8496

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 14 iterations
#
# Final cluster distortion: 2198.8405
# Cluster purity calculations:
# Average cluster purity: 0.7696 +/- 0.0147
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7830
# Classification BSR based on highest probability labels:
# BSR: 0.7696

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 9 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=9, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2169.7201
# Cluster purity calculations:
# Average cluster purity: 0.8089 +/- 0.0342
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7955
# Classification BSR based on highest probability labels:
# BSR: 0.8089

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=9, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 9 iterations
#
# Final cluster distortion: 2138.1110
# Cluster purity calculations:
# Average cluster purity: 0.7555 +/- 0.0207
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7531
# Classification BSR based on highest probability labels:
# BSR: 0.7555

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ### Gr(15,200)

# %%
sub, lbls = make_subspaces(data, labels, dim=15)

# %%
D = distances.geodesic_distance(sub, sub)
embed = distances.mds(D)

# %%
plt.figure()
for i in np.unique(lbls):
    idx = np.where(lbls == i)[0]
    plt.plot(embed[idx, 0], embed[idx, 1], 'o', label='Class %i' % i)
plt.legend()
plt.show()

# %% [markdown]
# ##### 3 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=3, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2276.6764
# Cluster purity calculations:
# Average cluster purity: 0.8112 +/- 0.0336
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7519
# Classification BSR based on highest probability labels:
# BSR: 0.8112

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=3, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 12 iterations
#
# Final cluster distortion: 2225.9620
# Cluster purity calculations:
# Average cluster purity: 0.7165 +/- 0.0368
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7556
# Classification BSR based on highest probability labels:
# BSR: 0.7165

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)

# %% [markdown]
# ##### 6 centers

# %%
kmeans = gr_kmeans.gr_kmeans(verbosity=0)
kmeans_centers, kmeans_labels = kmeans.fit(sub, true_labels=lbls, center_count=6, plot_results=True, 
                                           show_cluster_data=True, numits=100, dist_metric=dist_metric)
# Out:
# Kmeans terminated after 100 iterations
#
# Final cluster distortion: 2167.8219
# Cluster purity calculations:
# Average cluster purity: 0.8553 +/- 0.0327
# Classification accuracy based on highest probability labels:
# Accuracy: 0.7481
# Classification BSR based on highest probability labels:
# BSR: 0.8553

# %%
lbg = gr_lbg.gr_lbg(verbosity=0)
lbg_centers, lbg_labels = lbg.fit(sub, true_labels=lbls, show_cluster_data=True, center_count=6, plot_results=True, numits=100,
                                 dist_metric=dist_metric)
# Out:
# LBG terminated after 8 iterations
#
# Final cluster distortion: 2113.5971
# Cluster purity calculations:
# Average cluster purity: 0.8561 +/- 0.0171
# Classification accuracy based on highest probability labels:
# Accuracy: 0.8496
# Classification BSR based on highest probability labels:
# BSR: 0.8561

# %%
plots.method_comparison_plot(sub, lbls, kmeans_centers, lbg_centers, dist_metric=dist_metric)
